# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
% matplotlib inline

# %%
con = sqlite3.connect("../database/patent.sqlite3")
df = pd.read_sql("SELECT * from patent LIMIT 3", con)
df
# Out:
#      Patent Kind  Claims AppType AppNum       GDate  GYear     AppDate  \
# 0  03858241            6    None         1975-01-07   1975  1974-03-26
# 1  03858242            5    None         1975-01-07   1975  1973-04-16
# 2  03858243           12    None         1975-01-07   1975  1973-07-11
#
#    AppYear pattype
# 0     1974    None
# 1     1973    None
# 2     1973    None

# %%
df_claims = pd.read_sql("SELECT claims from patent", con)
df_claims
# Out:
#          Claims
# 0             6
# 1             5
# 2            12
# 3             1
# 4             5
# 5             6
# 6             4
# 7             5
# 8            17
# 9             1
# 10           17
# 11            5
# 12            6
# 13            2
# 14            3
# 15            3
# 16            1
# 17            6
# 18            6
# 19           10
# 20            2
# 21            8
# 22            3
# 23            8
# 24           10
# 25           16
# 26            3
# 27            4
# 28            5
# 29            2
# ...         ...
# 4823377      20
# 4823378      11
# 4823379      24
# 4823380      19
# 4823381      16
# 4823382      20
# 4823383      21
# 4823384      19
# 4823385      13
# 4823386      18
# 4823387      59
# 4823388      13
# 4823389      20
# 4823390      18
# 4823391      19
# 4823392      15
# 4823393      25
# 4823394      16
# 4823395      11
# 4823396      11
# 4823397      22
# 4823398      17
# 4823399      13
# ...

# %%
df_claims[df_claims['Claims'] > 200].hist()
plt.show()

# %%
df_claims.max()
# Out:
# Claims    887
# dtype: float64

# %%
df[df['Claims'] == 887]
# Out:
# Empty DataFrame
# Columns: [Patent, Kind, Claims, AppType, AppNum, GDate, GYear, AppDate, AppYear, pattype]
# Index: []

# %%
df_query = pd.read_sql("SELECT * from patent where claims = 887", con)

# %%
df_query
# Out:
#      Patent Kind  Claims  AppType   AppNum       GDate  GYear     AppDate  \
# 0  06684189   B1     887        8  8906736  2004-01-27   2004  1997-08-04
#
#    AppYear pattype
# 0     1997    None

# %%
con = sqlite3.connect("../database/citation.sqlite3")
df = pd.read_sql("SELECT patent, citation from citation", con)

# %%
df.to_csv('../data/full_citation.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53527305 entries, 0 to 53527304
# Data columns (total 2 columns):
# Patent      object
# Citation    object
# dtypes: object(2)
