# %%
import pandas as pd
import numpy as np
from datetime import date
import graphlab as gl
import networkx as nx
from collections import Counter, defaultdict
import matplotlib.pyplot as plt
import plotly.plotly as ply
from IPython.display import display
from IPython.display import Image
gl.canvas.set_target('ipynb')
# %matplotlib inline
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-895 - Server binary: /Users/youngstone/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1426113660.log
# [INFO] GraphLab Server Version: 1.3.0

# %%
df_data1 = pd.read_pickle('../data/dataframe.pkl')

# %%
df_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2465 entries, 0 to 2464
# Data columns (total 8 columns):
# Number                  2465 non-null object
# Title                   2465 non-null object
# Filing Date             2465 non-null datetime64[ns]
# US Patent References    2051 non-null object
# Abstract                2465 non-null object
# Other Classes           2439 non-null object
# Primary Class           2465 non-null object
# Claims                  2465 non-null object
# dtypes: datetime64[ns](1), object(7)

# %%
df_data2 = pd.read_csv('../data/full_pagerank.csv')

# %%
df_data2 = df_data2.rename(columns={'Patent': 'Number'})

# %%
df_data2['Number'] = df_data2['Number'].apply(lambda x: x[1:] if type(x) == str and x[0] == '0' else x)

# %%
pd.merge(df_data1, df_data2, on=['Number'], how='left')
# Out:
#        Number                                              Title Filing Date  \
# 0     8961986                                Peptide composition  2012-12-06
# 1     8962678                               Senescence inhibitor  2007-06-29
# 2     8449894  Aspergillus vaccine preparation and methods of...  2007-05-25
# 3     8968745  Method of treating cancer with an HLA-A*3303-r...  2013-12-31
# 4     8969524  FVIII peptides for immune tolerance induction ...  2011-10-27
# 5     8961982  Modulation of developmental immune programming...  2008-06-13
# 6     8961985  Immunotherapy against several tumors including...  2012-01-09
# 7     8961984              Surface-coated structures and methods  2010-10-07
# 8     8961992                             Epsigam fusion protein  2014-04-02
# 9     8961981  Targeting the neuromuscular junction for treat...  2012-06-19
# 10    8962548  ***WITHDRAWN PATENT AS PER THE LATEST USPTO WI...  2005-03-03
# ...

# %%
df_data2[df_data2['Number'] == '5080896']
# Out:
#            Number  pagerank
# 86325     5080896  0.241436
# 10571973  5080896  0.150000

# %%
df_data2
# Out:
#                      Number  pagerank
# 0                   6640407  0.425589
# 1                   6640400  1.095910
# 2                   6640387  2.754970
# 3                   6640385  0.243396
# 4                   6640379  0.514201
# 5                   6640343  0.256033
# 6                   6640296  0.454791
# 7                   6640293  0.300568
# 8                   6640280  0.178200
# 9                   6640267  0.235003
# 10                  6640258  0.277716
# 11                  6640257  0.320949
# 12                  6640255  0.171064
# 13                  6640239  0.265122
# 14                  6640231  0.335262
# 15                  6640206  0.178358
# 16                  6640197  0.199806
# 17                  6640182  0.227975
# 18                  6640179  0.327881
# 19                  6640164  0.507353
# 20                  6640106  0.200587
# 21                  6640094  0.315371
# 22                  6640043  0.441309
# 23                  6640008  0.352721
# ...
