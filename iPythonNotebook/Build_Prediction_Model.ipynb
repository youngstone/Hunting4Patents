# %%
# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly.plotly as py
from plotly.graph_objs import *
from IPython.display import display
from IPython.display import Image
import pandas as pd
import re
import cPickle as pkl
import json
import numpy as np
from collections import Counter
from datetime import datetime, date
from sklearn.grid_search import GridSearchCV

# %matplotlib inline

# %%
def run_on_start_2():
    print "loading dataframe..."
    with open('../data/patent_dataframe.pkl', 'rb') as handle:
        df = pkl.load(handle)
    return df

# %%
df = run_on_start_2()
# Out:
# loading dataframe...

# %%
cond = df['Filing Date'].apply(lambda x: type(x)) == pd.tslib.NaTType

# %%
df = df[~cond]

# %%
# df.info()

# %%
def events_count(entry):
    code = []
    if type(entry) != float:
        for event in entry:
            code.append(event['Code'])
    return Counter(code)

def get_code(entry):
    code = []
    if type(entry) != float:
        for event in entry:
            code.append(event['Code'])
    return code

def get_date(entry):
    date = []
    if type(entry) != float:
        for event in entry:
            dt = event['Date']
            dt_dt = datetime.strptime(dt, '%b %d, %Y')
            date.append(dt_dt)
    return date

# def get_event(entry):
#     case = []
#     if type(entry) != float:
#         for event in entry:
#             case.append(event['Code'])
#     return case

# %%
cod = df['legal-events'].apply(get_code)

dat = df['legal-events'].apply(get_date)

# %%
fil_dat = df['Filing Date']

# %%
def determine_early_termination(fil_dat, code):
    today = date.today() 
    screening_day = datetime(today.year - 20, today.month, today.day)
    if fil_dat.to_datetime() < screening_day:
        return 0
    elif 'FP' in code:
        return 1
    else:
        return -1

# %%
end = []
for d, e in zip(fil_dat, cod):
    end.append(determine_early_termination(d, e))

# %%
one = 0
zero = 0
minus_one = 0
for i in end:
    if i == 1:
        one += 1
    elif i == 0:
        zero += 1
    else:
        minus_one += 1

# %%
print one
print zero
print minus_one
# Out:
# 581
# 198
# 1682

# %%
582. / (197 + 582)
# Out:
# 0.7471116816431322

# %%
patent_status = pd.Series(data=end)

# %%
df['Patent Status'] = patent_status

# %%
screened_df = df[df['Patent Status'] != -1]

# %%
feature_names = [u'Patent Number',
                 u'Title', 
                 u'US Patent References', 
                 u'Abstract', 
                 u'Primary Class', 
                 u'Claims', 
                 u'backward-citations', 
                 u'npl-citations', 
                 u'backward-citations-by-examiner', 
                 u'backward-citations-by-inventor', 
                 u'forward-citations-by-examiner', 
                 u'forward-citations-by-inventor', 
                 u'Patent Status']

# %%
screened_df = screened_df[feature_names]
screened_df = screened_df.rename(columns={'Patent Number': 'Number'})

# %%
screened_df['num_of_claims'] = screened_df['Claims'].apply(len)

# %%
fwd_cit_ratio_inv_exm = []
fwd_cit_inv = screened_df['forward-citations-by-inventor']
fwd_cit_exm = screened_df['forward-citations-by-examiner']
fwd_cit_ratio_inv_exm = [float(i) / (i + e) for i, e in zip(fwd_cit_inv, fwd_cit_exm)]
# fwd_cit_ratio_inv_exm = [float(i)**2 / (i**2 + e**2) for i, e in zip(fwd_cit_inv, fwd_cit_exm)]
screened_df['fwd_cit_ratio_inv_exm'] = fwd_cit_ratio_inv_exm
screened_df['fwd_cit_ratio_inv_exm'] = screened_df['fwd_cit_ratio_inv_exm'].fillna(float(1))

# %%
bwd_cit_ratio_inv_exm = []
bwd_cit_inv = screened_df['backward-citations-by-inventor']
bwd_cit_exm = screened_df['backward-citations-by-examiner']
bwd_cit_ratio_inv_exm = [float(i) / (i + e) for i, e in zip(bwd_cit_inv, bwd_cit_exm)]
# bwd_cit_ratio_inv_exm = [float(i)**2 / (i**2 + e**2) for i, e in zip(bwd_cit_inv, bwd_cit_exm)]

screened_df['bwd_cit_ratio_inv_exm'] = bwd_cit_ratio_inv_exm
screened_df['bwd_cit_ratio_inv_exm'] = screened_df['bwd_cit_ratio_inv_exm'].fillna(float(1))

# %%
screened_df['bwd_pat_cit_count'] = screened_df['backward-citations'].apply(len)
screened_df['Primary Class'] = screened_df['Primary Class'].apply(lambda x: x[0])
screened_df['npl-citations'] = screened_df['npl-citations'].fillna(0)

# %%
screened_df['Claims'] = screened_df['Claims'].apply(lambda x: ' '.join(x))

# %%
# screened_df

# %%
drop_columns = ['US Patent References',
                'forward-citations-by-inventor', 
                'forward-citations-by-examiner',
                'backward-citations-by-inventor', 
                'backward-citations-by-examiner',
                'backward-citations']
df_model = screened_df.drop(drop_columns, axis=1)

# %%
df_model
# Out:
#        Number                                              Title  \
# 790   7833521  Methods of treating using hormone-albumin fusi...
# 792   7833536                         Mycoplasma subunit vaccine
# 802   7815911  Compositions and methods for treating Yersinia...
# 805   7811590  Haemophilus influenzae outer membrane protein ...
# 808   7811583  Antigens and vaccines against Piscirickettsia ...
# 810   7811575  Nucleic acids and corresponding proteins entit...
# 812   7811573  Compositions of antigens bound to HIV-1 Tat, f...
# 819   7807170          Protein A compositions and methods of use
# 821   7803909       Mutated Src oncogene composition and methods
# 822   7803382    Method for inducing immune response to NY-CO-58
# 824   7803381  Retro-inverso gonadotropin-releasing hormone p...
# 832   7790187  Chimeric recombinant antigens of Toxoplasma go...
# 834   7785609  Recombinant Haemophilus influenzae adhesin pro...
# 838   7785607  Immune diagnostic assay to diagnose and monito...
# 839   7785598  Alternate reading frame hepatitis C virus pept...
# 840   7785571                     Treatment of fungal infections
# 841   7780965                     Eta-1 gene and methods for use
# 845   7776335  Proteinase K resistant surface protein of Neis...
# 850   7767209  Modified vaccinia virus Ankara (MVA) mutant an...
# 863   7744906                                 Pain relief agents
# 870   7740833             Therapeutic uses of chemokine variants
# 887   7722876  Toxin-related antibodies with antimicrobial an...
# 888   7722888      Streptococcus pneumoniae proteins and nucleic
# 893   7718400  Methods of increasing lean tissue mass using O...
# 930   7678758  Method for enhancing T cell reactivity toward ...
# 931   7674465  Regulation of gene expression by the Bacillus ...
# 943   7658934             Chlamydia antigens and protein vaccine
# 944   7658928  Method of vaccination comprising administering...
# 945   7655247                                   Malaria vaccines
# 947   7655784  Trans-sialidases obtained from Trypanosoma con...
# ...       ...                                                ...
# 2431  5328991  Preparation of alkali-modified cat dander alle...
# 2432  5314991  Recombinant 40 KDa Dermatophagoides farinae al...
# 2433  5284935  MHC-mediated toxic conjugates useful in amelio...
# 2434  5262177  Recombinant viruses encoding the human melanom...
# 2435  5252556  Fragment capable of binding anti-CD43 autoanti...
# 2436  5229490                    Multiple antigen peptide system
# 2437  5219987  Sequential polypeptides endowed with immunolog...
# 2438  5194425  MHC-mediated toxic conjugates useful in amelio...
# 2439  5175148  Sperm antigen corresponding to a sperm autoant...
# 2440  5157020                   Synthetic senescent cell antigen
# 2441  5091363  Agent for the therapy of factor VIII-resistant...
# 2442  5080896                                Synthetic immunogen
# 2443  5073628                            Hyposensitization agent
# 2444  5068177  Anti-idiotype antibodies induced by synthetic ...
# 2445  5019383         Fatty acid carriers for synthetic peptides
# 2446  5019384        Immunonodulating compositions and their use
# 2447  4996297  Recombinantly expressed rabbit zona pellucida ...
# 2448  4968627  DNA fragments coding an immunogen peptide liab...
# 2449  4939239    Hyposensitization agent of cedar pollen antigen
# 2450  4864019  Antibodies to inhibin and conjugates produced ...
# 2451  4861864                                 Rotavirus antigens
# 2452  4857637  Methods and compositions for immunologically m...
# 2453  4716150  Synthetic peptides and use thereof in preparin...
# 2454  4608251  LHRH analogues useful in stimulating anti-LHRH...
# 2455  4596792  Safe vaccine for hepatitis containing polymeri...
# 2456  4554101  Identification and preparation of epitopes on ...
# 2457  4548923  Muramyl peptides and processes for their manuf...
# 2458  4499080  Synthetic ST toxin, process for its preparatio...
# 2459  4454121  Synthetic peptides corresponding to antigenic ...
# 2460  4107298  Antigenically active polypeptide and a process...
#
#                                                Abstract Primary Class  \
# 790   Biologically active polypeptides comprising a ...      424/85.4
# 792   The present invention relates i.a. to vaccines...     424/264.1
# 802   Compositions and methods for treating a Yersin...     424/192.1
# 805   This invention relates to recombinant bacteria...     424/256.1
# 808   The present invention discloses novel proteins...     424/234.1
# 810   A novel gene 158P3D2 and its encoded protein, ...     424/185.1
# 812   The present invention concerns a method for pr...     424/184.1
# 819   Methods and compositions for modulating an imm...     424/184.1
# 821   The present invention provides a mutant oligon...       530/350
# 822   The invention provides methods, compositions a...     424/185.1
# 824   The invention describes a retro-inverso (RI) g...     424/185.1
# 832   The invention described herein relates to a me...     424/273.1
# 834   Recombinant production of Hia protein, in full...     424/256.1
# 838   The present invention relates to a method of d...     424/248.1
# 839   Novel hepatitis C virus (HCV) polypeptides are...     424/189.1
# 840   A composition comprising an antibody or an ant...       424/9.2
# 841   The present application relates to osteopontin...     424/185.1
# 845   The identification of a highly conserved, immu...     424/185.1
# 850   The present invention is directed to a MVA mut...     424/199.1
# 863   The present invention concerns the use of a he...     424/248.1
# 870   Variants of homodimer-forming chemokines, such...      424/85.1
# 887   Anti-idiotypic antibodies which recognise the ...     424/184.1
# 888   Protein antigens from Streptococcus pneumoniae...     424/244.1
# 893   DNA sequences comprising nucleic acids encodin...      435/69.1
# 930   Provided is a method of vaccinating a patient ...      514/19.3
# 931   The invention provides a novel gene and protei...     424/185.1
# 943   The present invention provides vaccines for im...     424/263.1
# 944   Described is a vaccine which comprises at leas...     424/184.1
# 945   The invention provides isolated placental P. f...     424/272.1
# 947   The invention relates to novel enzymes, which ...      536/23.7
# ...                                                 ...           ...
# 2431  Proteins, referred to as modified human T cell...       530/403
# 2432  The present invention is directed to a recombi...       530/350
# 2433  The invention is directed to methods and mater...     424/185.1
# 2434  Peptides or proteins related to a melanoma ass...     435/235.1
# 2435  A fragment capable of binding to an anti-CD43 ...     424/185.1
# 2436  Multiple antigen peptide systems are described...       530/324
# 2437  Synthetic polypeptides constituted by at least...       530/324
# 2438  The invention is directed to methods and mater...     424/193.1
# 2439  Disclosed is a synthetic peptide, useful as an...     424/185.1
# 2440  Disclosed herein is a synthetic senescent cell...     424/185.1
# 2441  An agent for the therapy of hemophilia A which...     424/185.1
# 2442  The present invention concerns novel immunogen...     424/193.1
# 2443  A novel hyposensitization agent was prepared b...       530/379
# 2444  Chemically synthesized polypeptides containing...     424/131.1
# 2445  A synthetic vaccine is contemplated comprising...     424/194.1
# 2446  Novel methods or compositions are provided for...     424/184.1
# 2447  The invention relates to antigenic preparation...     424/185.1
# 2448  DNA fragment capable of coding for an immunoge...     435/320.1
# 2449  A novel hyposensitization agent was prepared b...       530/370
# 2450  A 32,000-Dalton protein with inhibin activity ...     424/139.1
# 2451  A soluble form of the neutralizing antigen or ...       530/324
# 2452  The activity of growth-associated receptors is...     424/185.1
# 2453  The compounds of the present invention are syn...      514/21.6
# 2454  A conjugate between a nona- or decapeptide of ...     424/185.1
# 2455  Methods and compositions are provided for an i...     424/185.1
# 2456  An immunoglobulin is provided which consists e...       530/324
# 2457  The compounds of the formula I ##STR1## in whi...     424/185.1
# 2458  The invention relates to novel synthetic pepti...     424/185.1
# 2459  Synthetic peptides corresponding to antigenic ...     424/185.1
# 2460  The invention provides for a synthetic antigen...     424/185.1
#
#                                                  Claims  npl-citations  \
# 790   1. A method of treating a patient in need of a...              2
# 792   1. A method for inducing the production of ant...             13
# 802   1. A composition for inducing an immune respon...             21
# 805   1. A non-typeable Haemophilus influenza major ...              7
# 808   1. A polypeptide that has an amino acid sequen...             49
# 810   1. A method of generating an immune response i...             44
# 812   1. A composition comprising an isolated, nativ...            124
# 819   1. A method for reducing an acute inflammatory...             41
# 821   1. An isolated truncated c-Src polypeptide of ...             49
# 822   1. A method of inducing or enhancing an immune...             30
# 824   1. A synthetic peptide comprising the amino ac...              5
# 832   1. A chimeric recombinant antigen containing a...             48
# 834   1. An immunogenic composition comprising a rec...             32
# 838   1. A peptide composition suitable to discrimin...              5
# 839   1. An isolated, purified, or synthetic polypep...             19
# 840   1. A composition comprising an antibody or an ...              0
# 841   1. An isolated polypeptide comprising the amin...             13
# 845   1. A method of preventing or treating a Neisse...             59
# 850   1. A MVA mutant, wherein the IL1βR coding sequ...             40
# 863   1. A method of relieving pain comprising admin...             67
# 870   1. A method for treating an autoimmune or infl...             15
# 887   1. An isolated polypeptide consisting of amino...             19
# 888   1. An isolated Streptococcus pneumoniae polype...             53
# 893   1. A process of producing a fusion protein com...             62
# 930   1. A method of treating a tumour by reducing o...             49
# 931   1. An isolated nucleic acid sequence selected ...              5
# 943   1. A vaccine composition comprising a substant...             81
# 944   1. A method of enhancing an immune response to...            125
# 945   1. An immunogenic composition comprising an am...              9
# 947   1. An isolated polynucleotide which encodes fo...              6
# ...                                                 ...            ...
# 2431  1. A modified Fel d I, substantially free of o...             34
# 2432  1. A substantially pure recombinant mite aller...             20
# 2433  1. A method for preparing a pharmaceutical com...            131
# 2434  1. A recombinant virus, the genome of which co...             87
# 2435  1. A method of treating a human patient infect...             29
# 2436  1. An antigenic product comprising a dendritic...              8
# 2437  1. Synthetic, sequential polypeptides endowed ...              5
# 2438  1. A composition comprising an MHC Class II co...             93
# 2439  1. A synthetic peptide, useful as an immunocon...             14
# 2440  1. A peptide consisting essentially of a molec...             26
# 2441  1. An agent for the therapy of Factor VIII inh...             12
# 2442  1. Compound containing an amphiphilic adjuvant...              6
# 2443  1. A conjugate, which comprises a saccharide c...              1
# 2444  1. A synthetic polypeptide having an amino aci...             58
# 2445  1. A synthetic antigen comprising a carrier co...             21
# 2446  1. A method for modulating the immune response...            116
# 2447  covered under Letters Patent is: 1. A substant...             79
# 2448  1. A DNA fragment which codes for a protein th...             16
# 2449  1. A hyposensitization agent for the preventio...              4
# 2450  1. Antibodies generated by a mammalian immune ...              4
# 2451  1. A neutralizing antigen of rotavirus compris...             14
# 2452  1. A method for immunizing an animal against i...             53
# 2453  1. A synthetic peptide immunogen for use in de...              8
# 2454  1. An immunogen vaccine which induces in a man...             22
# 2455  1. A method for protecting a host susceptible ...             37
# 2456  1. A method of synthesizing a peptide comprisi...             41
# 2457  1. The compounds of the formula I ##STR20## wh...              2
# 2458  1. A peptide (P) n free of intramolecular disu...              2
# 2459  1. A synthetic polypeptide having the followin...              2
# 2460  1. Synthetic antigenically active polypeptide,...              0
#
#       Patent Status  num_of_claims  fwd_cit_ratio_inv_exm  \
# 790               1             23               1.000000
# 792               1             11               1.000000
# 802               1             10               1.000000
# 805               1             10               0.000000
# 808               1              8               1.000000
# 810               1              5               1.000000
# 812               1             37               0.000000
# 819               1             37               1.000000
# 821               1             15               1.000000
# 822               1              4               1.000000
# 824               1             18               1.000000
# 832               1              6               1.000000
# 834               1             18               1.000000
# 838               1              4               0.000000
# 839               1             25               1.000000
# 840               1             27               1.000000
# 841               1              8               1.000000
# 845               1             10               1.000000
# 850               1             15               0.750000
# 863               1             20               1.000000
# 870               1             12               0.000000
# 887               1              6               0.000000
# 888               1              5               0.000000
# 893               1             13               1.000000
# 930               1             12               0.000000
# 931               1             18               1.000000
# 943               1             21               1.000000
# 944               1              6               0.000000
# 945               1              4               1.000000
# 947               1             18               1.000000
# ...             ...            ...                    ...
# 2431              0             11               0.857143
# 2432              0             16               0.769231
# 2433              0              8               0.575000
# 2434              0             34               0.814815
# 2435              0              5               0.000000
# 2436              0             33               0.734597
# 2437              0              3               0.000000
# 2438              0              6               0.480000
# 2439              0             14               0.214286
# 2440              0             37               0.545455
# 2441              0              6               0.250000
# 2442              0             50               0.352941
# 2443              0             27               0.700000
# 2444              0             35               0.555556
# 2445              0             21               0.521739
# 2446              0             13               0.678571
# 2447              0              7               0.086957
# 2448              0              9               0.000000
# 2449              0              6               0.708333
# 2450              0             15               0.076923
# 2451              0             12               0.312500
# 2452              0             10               0.310345
# 2453              0             50               0.750000
# 2454              0             29               0.742574
# 2455              0              6               0.797297
# 2456              0              6               0.850943
# 2457              0             17               0.222222
# 2458              0             34               0.181818
# 2459              0             12               0.767442
# 2460              0             12               0.000000
#
#       bwd_cit_ratio_inv_exm  bwd_pat_cit_count
# 790                0.000000                  2
# 792                1.000000                  2
# 802                0.000000                 12
# 805                1.000000                  1
# 808                1.000000                 24
# 810                0.833333                  6
# 812                0.909091                 11
# 819                0.979592                 49
# 821                0.600000                  5
# 822                0.846154                 13
# 824                0.333333                  3
# 832                1.000000                 43
# 834                1.000000                 26
# 838                1.000000                  5
# 839                1.000000                 12
# 840                1.000000                  3
# 841                1.000000                 22
# 845                0.900000                 20
# 850                0.750000                  4
# 863                1.000000                 19
# 870                0.375000                  8
# 887                0.615385                 13
# 888                0.866667                 15
# 893                0.981818                 55
# 930                0.714286                  7
# 931                1.000000                  5
# 943                1.000000                 34
# 944                1.000000                  6
# 945                1.000000                  0
# 947                1.000000                  0
# ...                     ...                ...
# 2431               0.000000                  5
# 2432               0.000000                  1
# 2433               0.000000                 12
# 2434               0.000000                  2
# 2435               0.000000                  1
# 2436               0.000000                  4
# 2437               0.000000                  5
# 2438               0.000000                  6
# 2439               0.000000                  1
# 2440               0.000000                  1
# 2441               0.000000                 14
# 2442               0.000000                  7
# 2443               0.000000                  1
# 2444               0.000000                  6
# 2445               0.000000                  8
# 2446               0.000000                  9
# 2447               0.000000                  4
# 2448               0.000000                  4
# 2449               0.000000                  2
# 2450               0.000000                  4
# 2451               1.000000                  0
# 2452               0.000000                  2
# 2453               1.000000                  0
# 2454               0.000000                  5
# 2455               0.000000                  1
# 2456               0.000000                 11
# 2457               0.000000                  6
# 2458               1.000000                  0
# 2459               1.000000                  0
# 2460               0.000000                  6
#
# [779 rows x 11 columns]

# %%
# df_model.set_index(['Number'])

# %%
save_path = '../data/df_model.pkl'
df_model.to_pickle(save_path)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import cPickle as pkl
from nltk.stem.snowball import SnowballStemmer
import re
from patent_tokenizer import PatentTokenizer


patent_tokenizer = PatentTokenizer()
patent_tokenizer.set_df(save_path)
patent_tokenizer.set_vectors()

patent_title_vectorizer = patent_tokenizer.get_title_vectorizer()
patent_abstract_vectorizer = patent_tokenizer.get_abstract_vectorizer()
patent_claims_vectorizer = patent_tokenizer.get_claims_vectorizer()

patent_title_vectors = patent_tokenizer.get_title_vectors()
patent_abstract_vectors = patent_tokenizer.get_abstract_vectors()
patent_claims_vectors = patent_tokenizer.get_claims_vectors()

# %%
print patent_title_vectors.shape
print patent_abstract_vectors.shape
print patent_claims_vectors.shape
# Out:
# (779, 1474)
# (779, 2000)
# (779, 2000)

# %%
claims_features_name = patent_claims_vectorizer.get_feature_names()

# %%
df_claims_features = pd.DataFrame(data=patent_claims_vectors, index=df_model.index, columns=claims_features_name)

# %%
df_merge = pd.merge(df_model, df_claims_features, how='inner', left_index=True, right_index=True)

# %%
df_merge
# Out:
#        Number                                              Title  \
# 790   7833521  Methods of treating using hormone-albumin fusi...
# 792   7833536                         Mycoplasma subunit vaccine
# 802   7815911  Compositions and methods for treating Yersinia...
# 805   7811590  Haemophilus influenzae outer membrane protein ...
# 808   7811583  Antigens and vaccines against Piscirickettsia ...
# 810   7811575  Nucleic acids and corresponding proteins entit...
# 812   7811573  Compositions of antigens bound to HIV-1 Tat, f...
# 819   7807170          Protein A compositions and methods of use
# 821   7803909       Mutated Src oncogene composition and methods
# 822   7803382    Method for inducing immune response to NY-CO-58
# 824   7803381  Retro-inverso gonadotropin-releasing hormone p...
# 832   7790187  Chimeric recombinant antigens of Toxoplasma go...
# 834   7785609  Recombinant Haemophilus influenzae adhesin pro...
# 838   7785607  Immune diagnostic assay to diagnose and monito...
# 839   7785598  Alternate reading frame hepatitis C virus pept...
# 840   7785571                     Treatment of fungal infections
# 841   7780965                     Eta-1 gene and methods for use
# 845   7776335  Proteinase K resistant surface protein of Neis...
# 850   7767209  Modified vaccinia virus Ankara (MVA) mutant an...
# 863   7744906                                 Pain relief agents
# 870   7740833             Therapeutic uses of chemokine variants
# 887   7722876  Toxin-related antibodies with antimicrobial an...
# 888   7722888      Streptococcus pneumoniae proteins and nucleic
# 893   7718400  Methods of increasing lean tissue mass using O...
# 930   7678758  Method for enhancing T cell reactivity toward ...
# 931   7674465  Regulation of gene expression by the Bacillus ...
# 943   7658934             Chlamydia antigens and protein vaccine
# 944   7658928  Method of vaccination comprising administering...
# 945   7655247                                   Malaria vaccines
# 947   7655784  Trans-sialidases obtained from Trypanosoma con...
# ...       ...                                                ...
# 2431  5328991  Preparation of alkali-modified cat dander alle...
# 2432  5314991  Recombinant 40 KDa Dermatophagoides farinae al...
# 2433  5284935  MHC-mediated toxic conjugates useful in amelio...
# 2434  5262177  Recombinant viruses encoding the human melanom...
# 2435  5252556  Fragment capable of binding anti-CD43 autoanti...
# 2436  5229490                    Multiple antigen peptide system
# 2437  5219987  Sequential polypeptides endowed with immunolog...
# 2438  5194425  MHC-mediated toxic conjugates useful in amelio...
# 2439  5175148  Sperm antigen corresponding to a sperm autoant...
# 2440  5157020                   Synthetic senescent cell antigen
# 2441  5091363  Agent for the therapy of factor VIII-resistant...
# 2442  5080896                                Synthetic immunogen
# 2443  5073628                            Hyposensitization agent
# 2444  5068177  Anti-idiotype antibodies induced by synthetic ...
# 2445  5019383         Fatty acid carriers for synthetic peptides
# 2446  5019384        Immunonodulating compositions and their use
# 2447  4996297  Recombinantly expressed rabbit zona pellucida ...
# 2448  4968627  DNA fragments coding an immunogen peptide liab...
# 2449  4939239    Hyposensitization agent of cedar pollen antigen
# 2450  4864019  Antibodies to inhibin and conjugates produced ...
# 2451  4861864                                 Rotavirus antigens
# 2452  4857637  Methods and compositions for immunologically m...
# 2453  4716150  Synthetic peptides and use thereof in preparin...
# 2454  4608251  LHRH analogues useful in stimulating anti-LHRH...
# 2455  4596792  Safe vaccine for hepatitis containing polymeri...
# 2456  4554101  Identification and preparation of epitopes on ...
# 2457  4548923  Muramyl peptides and processes for their manuf...
# 2458  4499080  Synthetic ST toxin, process for its preparatio...
# 2459  4454121  Synthetic peptides corresponding to antigenic ...
# 2460  4107298  Antigenically active polypeptide and a process...
#
#                                                Abstract Primary Class  \
# 790   Biologically active polypeptides comprising a ...      424/85.4
# 792   The present invention relates i.a. to vaccines...     424/264.1
# 802   Compositions and methods for treating a Yersin...     424/192.1
# 805   This invention relates to recombinant bacteria...     424/256.1
# 808   The present invention discloses novel proteins...     424/234.1
# 810   A novel gene 158P3D2 and its encoded protein, ...     424/185.1
# 812   The present invention concerns a method for pr...     424/184.1
# 819   Methods and compositions for modulating an imm...     424/184.1
# 821   The present invention provides a mutant oligon...       530/350
# 822   The invention provides methods, compositions a...     424/185.1
# 824   The invention describes a retro-inverso (RI) g...     424/185.1
# 832   The invention described herein relates to a me...     424/273.1
# 834   Recombinant production of Hia protein, in full...     424/256.1
# 838   The present invention relates to a method of d...     424/248.1
# 839   Novel hepatitis C virus (HCV) polypeptides are...     424/189.1
# 840   A composition comprising an antibody or an ant...       424/9.2
# 841   The present application relates to osteopontin...     424/185.1
# 845   The identification of a highly conserved, immu...     424/185.1
# 850   The present invention is directed to a MVA mut...     424/199.1
# 863   The present invention concerns the use of a he...     424/248.1
# 870   Variants of homodimer-forming chemokines, such...      424/85.1
# 887   Anti-idiotypic antibodies which recognise the ...     424/184.1
# 888   Protein antigens from Streptococcus pneumoniae...     424/244.1
# 893   DNA sequences comprising nucleic acids encodin...      435/69.1
# 930   Provided is a method of vaccinating a patient ...      514/19.3
# 931   The invention provides a novel gene and protei...     424/185.1
# 943   The present invention provides vaccines for im...     424/263.1
# 944   Described is a vaccine which comprises at leas...     424/184.1
# 945   The invention provides isolated placental P. f...     424/272.1
# 947   The invention relates to novel enzymes, which ...      536/23.7
# ...                                                 ...           ...
# 2431  Proteins, referred to as modified human T cell...       530/403
# 2432  The present invention is directed to a recombi...       530/350
# 2433  The invention is directed to methods and mater...     424/185.1
# 2434  Peptides or proteins related to a melanoma ass...     435/235.1
# 2435  A fragment capable of binding to an anti-CD43 ...     424/185.1
# 2436  Multiple antigen peptide systems are described...       530/324
# 2437  Synthetic polypeptides constituted by at least...       530/324
# 2438  The invention is directed to methods and mater...     424/193.1
# 2439  Disclosed is a synthetic peptide, useful as an...     424/185.1
# 2440  Disclosed herein is a synthetic senescent cell...     424/185.1
# 2441  An agent for the therapy of hemophilia A which...     424/185.1
# 2442  The present invention concerns novel immunogen...     424/193.1
# 2443  A novel hyposensitization agent was prepared b...       530/379
# 2444  Chemically synthesized polypeptides containing...     424/131.1
# 2445  A synthetic vaccine is contemplated comprising...     424/194.1
# 2446  Novel methods or compositions are provided for...     424/184.1
# 2447  The invention relates to antigenic preparation...     424/185.1
# 2448  DNA fragment capable of coding for an immunoge...     435/320.1
# 2449  A novel hyposensitization agent was prepared b...       530/370
# 2450  A 32,000-Dalton protein with inhibin activity ...     424/139.1
# 2451  A soluble form of the neutralizing antigen or ...       530/324
# 2452  The activity of growth-associated receptors is...     424/185.1
# 2453  The compounds of the present invention are syn...      514/21.6
# 2454  A conjugate between a nona- or decapeptide of ...     424/185.1
# 2455  Methods and compositions are provided for an i...     424/185.1
# 2456  An immunoglobulin is provided which consists e...       530/324
# 2457  The compounds of the formula I ##STR1## in whi...     424/185.1
# 2458  The invention relates to novel synthetic pepti...     424/185.1
# 2459  Synthetic peptides corresponding to antigenic ...     424/185.1
# 2460  The invention provides for a synthetic antigen...     424/185.1
#
#                                                  Claims  npl-citations  \
# 790   1. A method of treating a patient in need of a...              2
# 792   1. A method for inducing the production of ant...             13
# 802   1. A composition for inducing an immune respon...             21
# 805   1. A non-typeable Haemophilus influenza major ...              7
# 808   1. A polypeptide that has an amino acid sequen...             49
# 810   1. A method of generating an immune response i...             44
# 812   1. A composition comprising an isolated, nativ...            124
# 819   1. A method for reducing an acute inflammatory...             41
# 821   1. An isolated truncated c-Src polypeptide of ...             49
# 822   1. A method of inducing or enhancing an immune...             30
# 824   1. A synthetic peptide comprising the amino ac...              5
# 832   1. A chimeric recombinant antigen containing a...             48
# 834   1. An immunogenic composition comprising a rec...             32
# 838   1. A peptide composition suitable to discrimin...              5
# 839   1. An isolated, purified, or synthetic polypep...             19
# 840   1. A composition comprising an antibody or an ...              0
# 841   1. An isolated polypeptide comprising the amin...             13
# 845   1. A method of preventing or treating a Neisse...             59
# 850   1. A MVA mutant, wherein the IL1βR coding sequ...             40
# 863   1. A method of relieving pain comprising admin...             67
# 870   1. A method for treating an autoimmune or infl...             15
# 887   1. An isolated polypeptide consisting of amino...             19
# 888   1. An isolated Streptococcus pneumoniae polype...             53
# 893   1. A process of producing a fusion protein com...             62
# 930   1. A method of treating a tumour by reducing o...             49
# 931   1. An isolated nucleic acid sequence selected ...              5
# 943   1. A vaccine composition comprising a substant...             81
# 944   1. A method of enhancing an immune response to...            125
# 945   1. An immunogenic composition comprising an am...              9
# 947   1. An isolated polynucleotide which encodes fo...              6
# ...                                                 ...            ...
# 2431  1. A modified Fel d I, substantially free of o...             34
# 2432  1. A substantially pure recombinant mite aller...             20
# 2433  1. A method for preparing a pharmaceutical com...            131
# 2434  1. A recombinant virus, the genome of which co...             87
# 2435  1. A method of treating a human patient infect...             29
# 2436  1. An antigenic product comprising a dendritic...              8
# 2437  1. Synthetic, sequential polypeptides endowed ...              5
# 2438  1. A composition comprising an MHC Class II co...             93
# 2439  1. A synthetic peptide, useful as an immunocon...             14
# 2440  1. A peptide consisting essentially of a molec...             26
# 2441  1. An agent for the therapy of Factor VIII inh...             12
# 2442  1. Compound containing an amphiphilic adjuvant...              6
# 2443  1. A conjugate, which comprises a saccharide c...              1
# 2444  1. A synthetic polypeptide having an amino aci...             58
# 2445  1. A synthetic antigen comprising a carrier co...             21
# 2446  1. A method for modulating the immune response...            116
# 2447  covered under Letters Patent is: 1. A substant...             79
# 2448  1. A DNA fragment which codes for a protein th...             16
# 2449  1. A hyposensitization agent for the preventio...              4
# 2450  1. Antibodies generated by a mammalian immune ...              4
# 2451  1. A neutralizing antigen of rotavirus compris...             14
# 2452  1. A method for immunizing an animal against i...             53
# 2453  1. A synthetic peptide immunogen for use in de...              8
# 2454  1. An immunogen vaccine which induces in a man...             22
# 2455  1. A method for protecting a host susceptible ...             37
# 2456  1. A method of synthesizing a peptide comprisi...             41
# 2457  1. The compounds of the formula I ##STR20## wh...              2
# 2458  1. A peptide (P) n free of intramolecular disu...              2
# 2459  1. A synthetic polypeptide having the followin...              2
# 2460  1. Synthetic antigenically active polypeptide,...              0
#
#       Patent Status  num_of_claims  fwd_cit_ratio_inv_exm  \
# 790               1             23               1.000000
# 792               1             11               1.000000
# 802               1             10               1.000000
# 805               1             10               0.000000
# 808               1              8               1.000000
# 810               1              5               1.000000
# 812               1             37               0.000000
# 819               1             37               1.000000
# 821               1             15               1.000000
# 822               1              4               1.000000
# 824               1             18               1.000000
# 832               1              6               1.000000
# 834               1             18               1.000000
# 838               1              4               0.000000
# 839               1             25               1.000000
# 840               1             27               1.000000
# 841               1              8               1.000000
# 845               1             10               1.000000
# 850               1             15               0.750000
# 863               1             20               1.000000
# 870               1             12               0.000000
# 887               1              6               0.000000
# 888               1              5               0.000000
# 893               1             13               1.000000
# 930               1             12               0.000000
# 931               1             18               1.000000
# 943               1             21               1.000000
# 944               1              6               0.000000
# 945               1              4               1.000000
# 947               1             18               1.000000
# ...             ...            ...                    ...
# 2431              0             11               0.857143
# 2432              0             16               0.769231
# 2433              0              8               0.575000
# 2434              0             34               0.814815
# 2435              0              5               0.000000
# 2436              0             33               0.734597
# 2437              0              3               0.000000
# 2438              0              6               0.480000
# 2439              0             14               0.214286
# 2440              0             37               0.545455
# 2441              0              6               0.250000
# 2442              0             50               0.352941
# 2443              0             27               0.700000
# 2444              0             35               0.555556
# 2445              0             21               0.521739
# 2446              0             13               0.678571
# 2447              0              7               0.086957
# 2448              0              9               0.000000
# 2449              0              6               0.708333
# 2450              0             15               0.076923
# 2451              0             12               0.312500
# 2452              0             10               0.310345
# 2453              0             50               0.750000
# 2454              0             29               0.742574
# 2455              0              6               0.797297
# 2456              0              6               0.850943
# 2457              0             17               0.222222
# 2458              0             34               0.181818
# 2459              0             12               0.767442
# 2460              0             12               0.000000
#
#       bwd_cit_ratio_inv_exm          ...            zipper      zona  zpb  \
# 790                0.000000          ...                 0  0.000000    0
# 792                1.000000          ...                 0  0.000000    0
# 802                0.000000          ...                 0  0.000000    0
# 805                1.000000          ...                 0  0.000000    0
# 808                1.000000          ...                 0  0.000000    0
# 810                0.833333          ...                 0  0.000000    0
# 812                0.909091          ...                 0  0.000000    0
# 819                0.979592          ...                 0  0.000000    0
# 821                0.600000          ...                 0  0.000000    0
# 822                0.846154          ...                 0  0.000000    0
# 824                0.333333          ...                 0  0.000000    0
# 832                1.000000          ...                 0  0.000000    0
# 834                1.000000          ...                 0  0.000000    0
# 838                1.000000          ...                 0  0.000000    0
# 839                1.000000          ...                 0  0.000000    0
# 840                1.000000          ...                 0  0.000000    0
# 841                1.000000          ...                 0  0.000000    0
# 845                0.900000          ...                 0  0.000000    0
# 850                0.750000          ...                 0  0.000000    0
# 863                1.000000          ...                 0  0.000000    0
# 870                0.375000          ...                 0  0.000000    0
# 887                0.615385          ...                 0  0.000000    0
# 888                0.866667          ...                 0  0.000000    0
# 893                0.981818          ...                 0  0.000000    0
# 930                0.714286          ...                 0  0.000000    0
# 931                1.000000          ...                 0  0.000000    0
# 943                1.000000          ...                 0  0.000000    0
# 944                1.000000          ...                 0  0.000000    0
# 945                1.000000          ...                 0  0.000000    0
# 947                1.000000          ...                 0  0.000000    0
# ...                     ...          ...               ...       ...  ...
# 2431               0.000000          ...                 0  0.000000    0
# 2432               0.000000          ...                 0  0.000000    0
# 2433               0.000000          ...                 0  0.000000    0
# 2434               0.000000          ...                 0  0.000000    0
# 2435               0.000000          ...                 0  0.000000    0
# 2436               0.000000          ...                 0  0.000000    0
# 2437               0.000000          ...                 0  0.000000    0
# 2438               0.000000          ...                 0  0.000000    0
# 2439               0.000000          ...                 0  0.000000    0
# 2440               0.000000          ...                 0  0.000000    0
# 2441               0.000000          ...                 0  0.000000    0
# 2442               0.000000          ...                 0  0.000000    0
# 2443               0.000000          ...                 0  0.000000    0
# 2444               0.000000          ...                 0  0.000000    0
# 2445               0.000000          ...                 0  0.000000    0
# 2446               0.000000          ...                 0  0.000000    0
# 2447               0.000000          ...                 0  0.294424    0
# 2448               0.000000          ...                 0  0.000000    0
# 2449               0.000000          ...                 0  0.000000    0
# 2450               0.000000          ...                 0  0.000000    0
# 2451               1.000000          ...                 0  0.000000    0
# 2452               0.000000          ...                 0  0.000000    0
# 2453               1.000000          ...                 0  0.000000    0
# 2454               0.000000          ...                 0  0.000000    0
# 2455               0.000000          ...                 0  0.000000    0
# 2456               0.000000          ...                 0  0.000000    0
# 2457               0.000000          ...                 0  0.000000    0
# 2458               1.000000          ...                 0  0.000000    0
# 2459               1.000000          ...                 0  0.000000    0
# 2460               0.000000          ...                 0  0.000000    0
#
#       zpc  α1  β2  β2m  βgal        μg  μm
# 790     0   0   0    0     0  0.000000   0
# 792     0   0   0    0     0  0.000000   0
# 802     0   0   0    0     0  0.000000   0
# 805     0   0   0    0     0  0.000000   0
# 808     0   0   0    0     0  0.000000   0
# 810     0   0   0    0     0  0.000000   0
# 812     0   0   0    0     0  0.000000   0
# 819     0   0   0    0     0  0.000000   0
# 821     0   0   0    0     0  0.000000   0
# 822     0   0   0    0     0  0.000000   0
# 824     0   0   0    0     0  0.000000   0
# 832     0   0   0    0     0  0.000000   0
# 834     0   0   0    0     0  0.000000   0
# 838     0   0   0    0     0  0.000000   0
# 839     0   0   0    0     0  0.000000   0
# 840     0   0   0    0     0  0.000000   0
# 841     0   0   0    0     0  0.000000   0
# 845     0   0   0    0     0  0.000000   0
# 850     0   0   0    0     0  0.000000   0
# 863     0   0   0    0     0  0.000000   0
# 870     0   0   0    0     0  0.000000   0
# 887     0   0   0    0     0  0.000000   0
# 888     0   0   0    0     0  0.000000   0
# 893     0   0   0    0     0  0.000000   0
# 930     0   0   0    0     0  0.000000   0
# 931     0   0   0    0     0  0.000000   0
# 943     0   0   0    0     0  0.000000   0
# 944     0   0   0    0     0  0.000000   0
# 945     0   0   0    0     0  0.000000   0
# 947     0   0   0    0     0  0.000000   0
# ...   ...  ..  ..  ...   ...       ...  ..
# 2431    0   0   0    0     0  0.000000   0
# 2432    0   0   0    0     0  0.000000   0
# 2433    0   0   0    0     0  0.000000   0
# 2434    0   0   0    0     0  0.000000   0
# 2435    0   0   0    0     0  0.000000   0
# 2436    0   0   0    0     0  0.000000   0
# 2437    0   0   0    0     0  0.000000   0
# 2438    0   0   0    0     0  0.000000   0
# 2439    0   0   0    0     0  0.000000   0
# 2440    0   0   0    0     0  0.000000   0
# 2441    0   0   0    0     0  0.053102   0
# 2442    0   0   0    0     0  0.000000   0
# 2443    0   0   0    0     0  0.000000   0
# 2444    0   0   0    0     0  0.000000   0
# 2445    0   0   0    0     0  0.000000   0
# 2446    0   0   0    0     0  0.000000   0
# 2447    0   0   0    0     0  0.000000   0
# 2448    0   0   0    0     0  0.000000   0
# 2449    0   0   0    0     0  0.000000   0
# 2450    0   0   0    0     0  0.000000   0
# 2451    0   0   0    0     0  0.000000   0
# 2452    0   0   0    0     0  0.000000   0
# 2453    0   0   0    0     0  0.000000   0
# 2454    0   0   0    0     0  0.000000   0
# 2455    0   0   0    0     0  0.000000   0
# 2456    0   0   0    0     0  0.000000   0
# 2457    0   0   0    0     0  0.000000   0
# 2458    0   0   0    0     0  0.000000   0
# 2459    0   0   0    0     0  0.000000   0
# 2460    0   0   0    0     0  0.000000   0
#
# [779 rows x 2011 columns]

# %%
target = df_merge['Patent Status']

# %%
non_needed = ['Number', 'Title', 'Abstract', 'Claims', 'Patent Status']
features = df_merge.drop(non_needed, axis=1)

# %%
features
# Out:
#      Primary Class  npl-citations  num_of_claims  fwd_cit_ratio_inv_exm  \
# 790       424/85.4              2             23               1.000000
# 792      424/264.1             13             11               1.000000
# 802      424/192.1             21             10               1.000000
# 805      424/256.1              7             10               0.000000
# 808      424/234.1             49              8               1.000000
# 810      424/185.1             44              5               1.000000
# 812      424/184.1            124             37               0.000000
# 819      424/184.1             41             37               1.000000
# 821        530/350             49             15               1.000000
# 822      424/185.1             30              4               1.000000
# 824      424/185.1              5             18               1.000000
# 832      424/273.1             48              6               1.000000
# 834      424/256.1             32             18               1.000000
# 838      424/248.1              5              4               0.000000
# 839      424/189.1             19             25               1.000000
# 840        424/9.2              0             27               1.000000
# 841      424/185.1             13              8               1.000000
# 845      424/185.1             59             10               1.000000
# 850      424/199.1             40             15               0.750000
# 863      424/248.1             67             20               1.000000
# 870       424/85.1             15             12               0.000000
# 887      424/184.1             19              6               0.000000
# 888      424/244.1             53              5               0.000000
# 893       435/69.1             62             13               1.000000
# 930       514/19.3             49             12               0.000000
# 931      424/185.1              5             18               1.000000
# 943      424/263.1             81             21               1.000000
# 944      424/184.1            125              6               0.000000
# 945      424/272.1              9              4               1.000000
# 947       536/23.7              6             18               1.000000
# ...            ...            ...            ...                    ...
# 2431       530/403             34             11               0.857143
# 2432       530/350             20             16               0.769231
# 2433     424/185.1            131              8               0.575000
# 2434     435/235.1             87             34               0.814815
# 2435     424/185.1             29              5               0.000000
# 2436       530/324              8             33               0.734597
# 2437       530/324              5              3               0.000000
# 2438     424/193.1             93              6               0.480000
# 2439     424/185.1             14             14               0.214286
# 2440     424/185.1             26             37               0.545455
# 2441     424/185.1             12              6               0.250000
# 2442     424/193.1              6             50               0.352941
# 2443       530/379              1             27               0.700000
# 2444     424/131.1             58             35               0.555556
# 2445     424/194.1             21             21               0.521739
# 2446     424/184.1            116             13               0.678571
# 2447     424/185.1             79              7               0.086957
# 2448     435/320.1             16              9               0.000000
# 2449       530/370              4              6               0.708333
# 2450     424/139.1              4             15               0.076923
# 2451       530/324             14             12               0.312500
# 2452     424/185.1             53             10               0.310345
# 2453      514/21.6              8             50               0.750000
# 2454     424/185.1             22             29               0.742574
# 2455     424/185.1             37              6               0.797297
# 2456       530/324             41              6               0.850943
# 2457     424/185.1              2             17               0.222222
# 2458     424/185.1              2             34               0.181818
# 2459     424/185.1              2             12               0.767442
# 2460     424/185.1              0             12               0.000000
#
#       bwd_cit_ratio_inv_exm  bwd_pat_cit_count       000   0001       001  \
# 790                0.000000                  2  0.000000  0.000  0.000000
# 792                1.000000                  2  0.000000  0.000  0.000000
# 802                0.000000                 12  0.000000  0.000  0.000000
# 805                1.000000                  1  0.000000  0.000  0.000000
# 808                1.000000                 24  0.000000  0.000  0.000000
# 810                0.833333                  6  0.000000  0.000  0.000000
# 812                0.909091                 11  0.000000  0.000  0.000000
# 819                0.979592                 49  0.000000  0.000  0.000000
# 821                0.600000                  5  0.000000  0.000  0.000000
# 822                0.846154                 13  0.000000  0.000  0.000000
# 824                0.333333                  3  0.000000  0.000  0.000000
# 832                1.000000                 43  0.000000  0.000  0.000000
# 834                1.000000                 26  0.000000  0.000  0.000000
# 838                1.000000                  5  0.000000  0.000  0.000000
# 839                1.000000                 12  0.000000  0.000  0.000000
# 840                1.000000                  3  0.000000  0.000  0.000000
# 841                1.000000                 22  0.000000  0.000  0.000000
# 845                0.900000                 20  0.000000  0.000  0.000000
# 850                0.750000                  4  0.000000  0.000  0.000000
# 863                1.000000                 19  0.029869  0.086  0.000000
# 870                0.375000                  8  0.000000  0.000  0.000000
# 887                0.615385                 13  0.000000  0.000  0.000000
# 888                0.866667                 15  0.000000  0.000  0.000000
# 893                0.981818                 55  0.000000  0.000  0.000000
# 930                0.714286                  7  0.000000  0.000  0.000000
# 931                1.000000                  5  0.000000  0.000  0.000000
# 943                1.000000                 34  0.000000  0.000  0.000000
# 944                1.000000                  6  0.000000  0.000  0.000000
# 945                1.000000                  0  0.000000  0.000  0.000000
# 947                1.000000                  0  0.000000  0.000  0.000000
# ...                     ...                ...       ...    ...       ...
# 2431               0.000000                  5  0.000000  0.000  0.000000
# 2432               0.000000                  1  0.016267  0.000  0.000000
# 2433               0.000000                 12  0.000000  0.000  0.000000
# 2434               0.000000                  2  0.000000  0.000  0.000000
# 2435               0.000000                  1  0.000000  0.000  0.000000
# 2436               0.000000                  4  0.000000  0.000  0.000000
# 2437               0.000000                  5  0.000000  0.000  0.000000
# 2438               0.000000                  6  0.000000  0.000  0.000000
# 2439               0.000000                  1  0.000000  0.000  0.000000
# 2440               0.000000                  1  0.000000  0.000  0.000000
# 2441               0.000000                 14  0.000000  0.000  0.000000
# 2442               0.000000                  7  0.000000  0.000  0.000000
# 2443               0.000000                  1  0.202959  0.000  0.051728
# 2444               0.000000                  6  0.000000  0.000  0.000000
# 2445               0.000000                  8  0.000000  0.000  0.000000
# 2446               0.000000                  9  0.000000  0.000  0.000000
# 2447               0.000000                  4  0.000000  0.000  0.000000
# 2448               0.000000                  4  0.000000  0.000  0.000000
# 2449               0.000000                  2  0.000000  0.000  0.000000
# 2450               0.000000                  4  0.000000  0.000  0.000000
# 2451               1.000000                  0  0.000000  0.000  0.000000
# 2452               0.000000                  2  0.000000  0.000  0.000000
# 2453               1.000000                  0  0.000000  0.000  0.000000
# 2454               0.000000                  5  0.037909  0.000  0.000000
# 2455               0.000000                  1  0.000000  0.000  0.000000
# 2456               0.000000                 11  0.000000  0.000  0.000000
# 2457               0.000000                  6  0.000000  0.000  0.000000
# 2458               1.000000                  0  0.000000  0.000  0.000000
# 2459               1.000000                  0  0.000000  0.000  0.000000
# 2460               0.000000                  6  0.000000  0.000  0.000000
#
#             01    ...     zipper      zona  zpb  zpc  α1  β2  β2m  βgal  \
# 790   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 792   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 802   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 805   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 808   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 810   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 812   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 819   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 821   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 822   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 824   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 832   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 834   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 838   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 839   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 840   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 841   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 845   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 850   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 863   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 870   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 887   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 888   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 893   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 930   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 931   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 943   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 944   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 945   0.000000    ...          0  0.000000    0    0   0   0    0     0
# 947   0.000000    ...          0  0.000000    0    0   0   0    0     0
# ...        ...    ...        ...       ...  ...  ...  ..  ..  ...   ...
# 2431  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2432  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2433  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2434  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2435  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2436  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2437  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2438  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2439  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2440  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2441  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2442  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2443  0.022122    ...          0  0.000000    0    0   0   0    0     0
# 2444  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2445  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2446  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2447  0.000000    ...          0  0.294424    0    0   0   0    0     0
# 2448  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2449  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2450  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2451  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2452  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2453  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2454  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2455  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2456  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2457  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2458  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2459  0.000000    ...          0  0.000000    0    0   0   0    0     0
# 2460  0.000000    ...          0  0.000000    0    0   0   0    0     0
#
#             μg  μm
# 790   0.000000   0
# 792   0.000000   0
# 802   0.000000   0
# 805   0.000000   0
# 808   0.000000   0
# 810   0.000000   0
# 812   0.000000   0
# 819   0.000000   0
# 821   0.000000   0
# 822   0.000000   0
# 824   0.000000   0
# 832   0.000000   0
# 834   0.000000   0
# 838   0.000000   0
# 839   0.000000   0
# 840   0.000000   0
# 841   0.000000   0
# 845   0.000000   0
# 850   0.000000   0
# 863   0.000000   0
# 870   0.000000   0
# 887   0.000000   0
# 888   0.000000   0
# 893   0.000000   0
# 930   0.000000   0
# 931   0.000000   0
# 943   0.000000   0
# 944   0.000000   0
# 945   0.000000   0
# 947   0.000000   0
# ...        ...  ..
# 2431  0.000000   0
# 2432  0.000000   0
# 2433  0.000000   0
# 2434  0.000000   0
# 2435  0.000000   0
# 2436  0.000000   0
# 2437  0.000000   0
# 2438  0.000000   0
# 2439  0.000000   0
# 2440  0.000000   0
# 2441  0.053102   0
# 2442  0.000000   0
# 2443  0.000000   0
# 2444  0.000000   0
# 2445  0.000000   0
# 2446  0.000000   0
# 2447  0.000000   0
# 2448  0.000000   0
# 2449  0.000000   0
# 2450  0.000000   0
# 2451  0.000000   0
# 2452  0.000000   0
# 2453  0.000000   0
# 2454  0.000000   0
# 2455  0.000000   0
# 2456  0.000000   0
# 2457  0.000000   0
# 2458  0.000000   0
# 2459  0.000000   0
# 2460  0.000000   0
#
# [779 rows x 2006 columns]

# %%
from pandas.core.reshape import get_dummies

# %%
# cols_v = get_dummies(df['venue_country'], dummy_na=True, prefix='venue_country')
dummy_class = get_dummies(features['Primary Class'], dummy_na=True, prefix='primary_class')

# %%
df_rf_features = pd.merge(features, dummy_class, how='inner', left_index=True, right_index=True)

# %%
df_rf_features = df_rf_features.drop(['Primary Class'], axis=1)

# %%
df_rf_features < 0
# Out:
#      npl-citations num_of_claims fwd_cit_ratio_inv_exm bwd_cit_ratio_inv_exm  \
# 790          False         False                 False                 False
# 792          False         False                 False                 False
# 802          False         False                 False                 False
# 805          False         False                 False                 False
# 808          False         False                 False                 False
# 810          False         False                 False                 False
# 812          False         False                 False                 False
# 819          False         False                 False                 False
# 821          False         False                 False                 False
# 822          False         False                 False                 False
# 824          False         False                 False                 False
# 832          False         False                 False                 False
# 834          False         False                 False                 False
# 838          False         False                 False                 False
# 839          False         False                 False                 False
# 840          False         False                 False                 False
# 841          False         False                 False                 False
# 845          False         False                 False                 False
# 850          False         False                 False                 False
# 863          False         False                 False                 False
# 870          False         False                 False                 False
# 887          False         False                 False                 False
# 888          False         False                 False                 False
# 893          False         False                 False                 False
# 930          False         False                 False                 False
# 931          False         False                 False                 False
# 943          False         False                 False                 False
# 944          False         False                 False                 False
# 945          False         False                 False                 False
# 947          False         False                 False                 False
# ...            ...           ...                   ...                   ...
# 2431         False         False                 False                 False
# 2432         False         False                 False                 False
# 2433         False         False                 False                 False
# 2434         False         False                 False                 False
# 2435         False         False                 False                 False
# 2436         False         False                 False                 False
# 2437         False         False                 False                 False
# 2438         False         False                 False                 False
# 2439         False         False                 False                 False
# 2440         False         False                 False                 False
# 2441         False         False                 False                 False
# 2442         False         False                 False                 False
# 2443         False         False                 False                 False
# 2444         False         False                 False                 False
# 2445         False         False                 False                 False
# 2446         False         False                 False                 False
# 2447         False         False                 False                 False
# 2448         False         False                 False                 False
# 2449         False         False                 False                 False
# 2450         False         False                 False                 False
# 2451         False         False                 False                 False
# 2452         False         False                 False                 False
# 2453         False         False                 False                 False
# 2454         False         False                 False                 False
# 2455         False         False                 False                 False
# 2456         False         False                 False                 False
# 2457         False         False                 False                 False
# 2458         False         False                 False                 False
# 2459         False         False                 False                 False
# 2460         False         False                 False                 False
#
#      bwd_pat_cit_count    000   0001    001     01   0101  ...    \
# 790              False  False  False  False  False  False  ...
# 792              False  False  False  False  False  False  ...
# 802              False  False  False  False  False  False  ...
# 805              False  False  False  False  False  False  ...
# 808              False  False  False  False  False  False  ...
# 810              False  False  False  False  False  False  ...
# 812              False  False  False  False  False  False  ...
# 819              False  False  False  False  False  False  ...
# 821              False  False  False  False  False  False  ...
# 822              False  False  False  False  False  False  ...
# 824              False  False  False  False  False  False  ...
# 832              False  False  False  False  False  False  ...
# 834              False  False  False  False  False  False  ...
# 838              False  False  False  False  False  False  ...
# 839              False  False  False  False  False  False  ...
# 840              False  False  False  False  False  False  ...
# 841              False  False  False  False  False  False  ...
# 845              False  False  False  False  False  False  ...
# 850              False  False  False  False  False  False  ...
# 863              False  False  False  False  False  False  ...
# 870              False  False  False  False  False  False  ...
# 887              False  False  False  False  False  False  ...
# 888              False  False  False  False  False  False  ...
# 893              False  False  False  False  False  False  ...
# 930              False  False  False  False  False  False  ...
# 931              False  False  False  False  False  False  ...
# 943              False  False  False  False  False  False  ...
# 944              False  False  False  False  False  False  ...
# 945              False  False  False  False  False  False  ...
# 947              False  False  False  False  False  False  ...
# ...                ...    ...    ...    ...    ...    ...  ...
# 2431             False  False  False  False  False  False  ...
# 2432             False  False  False  False  False  False  ...
# 2433             False  False  False  False  False  False  ...
# 2434             False  False  False  False  False  False  ...
# 2435             False  False  False  False  False  False  ...
# 2436             False  False  False  False  False  False  ...
# 2437             False  False  False  False  False  False  ...
# 2438             False  False  False  False  False  False  ...
# 2439             False  False  False  False  False  False  ...
# 2440             False  False  False  False  False  False  ...
# 2441             False  False  False  False  False  False  ...
# 2442             False  False  False  False  False  False  ...
# 2443             False  False  False  False  False  False  ...
# 2444             False  False  False  False  False  False  ...
# 2445             False  False  False  False  False  False  ...
# 2446             False  False  False  False  False  False  ...
# 2447             False  False  False  False  False  False  ...
# 2448             False  False  False  False  False  False  ...
# 2449             False  False  False  False  False  False  ...
# 2450             False  False  False  False  False  False  ...
# 2451             False  False  False  False  False  False  ...
# 2452             False  False  False  False  False  False  ...
# 2453             False  False  False  False  False  False  ...
# 2454             False  False  False  False  False  False  ...
# 2455             False  False  False  False  False  False  ...
# 2456             False  False  False  False  False  False  ...
# 2457             False  False  False  False  False  False  ...
# 2458             False  False  False  False  False  False  ...
# 2459             False  False  False  False  False  False  ...
# 2460             False  False  False  False  False  False  ...
#
#      primary_class_536/20 primary_class_536/22.1 primary_class_536/23.1  \
# 790                 False                  False                  False
# 792                 False                  False                  False
# 802                 False                  False                  False
# 805                 False                  False                  False
# 808                 False                  False                  False
# 810                 False                  False                  False
# 812                 False                  False                  False
# 819                 False                  False                  False
# 821                 False                  False                  False
# 822                 False                  False                  False
# 824                 False                  False                  False
# 832                 False                  False                  False
# 834                 False                  False                  False
# 838                 False                  False                  False
# 839                 False                  False                  False
# 840                 False                  False                  False
# 841                 False                  False                  False
# 845                 False                  False                  False
# 850                 False                  False                  False
# 863                 False                  False                  False
# 870                 False                  False                  False
# 887                 False                  False                  False
# 888                 False                  False                  False
# 893                 False                  False                  False
# 930                 False                  False                  False
# 931                 False                  False                  False
# 943                 False                  False                  False
# 944                 False                  False                  False
# 945                 False                  False                  False
# 947                 False                  False                  False
# ...                   ...                    ...                    ...
# 2431                False                  False                  False
# 2432                False                  False                  False
# 2433                False                  False                  False
# 2434                False                  False                  False
# 2435                False                  False                  False
# 2436                False                  False                  False
# 2437                False                  False                  False
# 2438                False                  False                  False
# 2439                False                  False                  False
# 2440                False                  False                  False
# 2441                False                  False                  False
# 2442                False                  False                  False
# 2443                False                  False                  False
# 2444                False                  False                  False
# 2445                False                  False                  False
# 2446                False                  False                  False
# 2447                False                  False                  False
# 2448                False                  False                  False
# 2449                False                  False                  False
# 2450                False                  False                  False
# 2451                False                  False                  False
# 2452                False                  False                  False
# 2453                False                  False                  False
# 2454                False                  False                  False
# 2455                False                  False                  False
# 2456                False                  False                  False
# 2457                False                  False                  False
# 2458                False                  False                  False
# 2459                False                  False                  False
# 2460                False                  False                  False
#
#      primary_class_536/23.4 primary_class_536/23.5 primary_class_536/23.7  \
# 790                   False                  False                  False
# 792                   False                  False                  False
# 802                   False                  False                  False
# 805                   False                  False                  False
# 808                   False                  False                  False
# 810                   False                  False                  False
# 812                   False                  False                  False
# 819                   False                  False                  False
# 821                   False                  False                  False
# 822                   False                  False                  False
# 824                   False                  False                  False
# 832                   False                  False                  False
# 834                   False                  False                  False
# 838                   False                  False                  False
# 839                   False                  False                  False
# 840                   False                  False                  False
# 841                   False                  False                  False
# 845                   False                  False                  False
# 850                   False                  False                  False
# 863                   False                  False                  False
# 870                   False                  False                  False
# 887                   False                  False                  False
# 888                   False                  False                  False
# 893                   False                  False                  False
# 930                   False                  False                  False
# 931                   False                  False                  False
# 943                   False                  False                  False
# 944                   False                  False                  False
# 945                   False                  False                  False
# 947                   False                  False                  False
# ...                     ...                    ...                    ...
# 2431                  False                  False                  False
# 2432                  False                  False                  False
# 2433                  False                  False                  False
# 2434                  False                  False                  False
# 2435                  False                  False                  False
# 2436                  False                  False                  False
# 2437                  False                  False                  False
# 2438                  False                  False                  False
# 2439                  False                  False                  False
# 2440                  False                  False                  False
# 2441                  False                  False                  False
# 2442                  False                  False                  False
# 2443                  False                  False                  False
# 2444                  False                  False                  False
# 2445                  False                  False                  False
# 2446                  False                  False                  False
# 2447                  False                  False                  False
# 2448                  False                  False                  False
# 2449                  False                  False                  False
# 2450                  False                  False                  False
# 2451                  False                  False                  False
# 2452                  False                  False                  False
# 2453                  False                  False                  False
# 2454                  False                  False                  False
# 2455                  False                  False                  False
# 2456                  False                  False                  False
# 2457                  False                  False                  False
# 2458                  False                  False                  False
# 2459                  False                  False                  False
# 2460                  False                  False                  False
#
#      primary_class_536/23.72 primary_class_536/23.74 primary_class_800/8  \
# 790                    False                   False               False
# 792                    False                   False               False
# 802                    False                   False               False
# 805                    False                   False               False
# 808                    False                   False               False
# 810                    False                   False               False
# 812                    False                   False               False
# 819                    False                   False               False
# 821                    False                   False               False
# 822                    False                   False               False
# 824                    False                   False               False
# 832                    False                   False               False
# 834                    False                   False               False
# 838                    False                   False               False
# 839                    False                   False               False
# 840                    False                   False               False
# 841                    False                   False               False
# 845                    False                   False               False
# 850                    False                   False               False
# 863                    False                   False               False
# 870                    False                   False               False
# 887                    False                   False               False
# 888                    False                   False               False
# 893                    False                   False               False
# 930                    False                   False               False
# 931                    False                   False               False
# 943                    False                   False               False
# 944                    False                   False               False
# 945                    False                   False               False
# 947                    False                   False               False
# ...                      ...                     ...                 ...
# 2431                   False                   False               False
# 2432                   False                   False               False
# 2433                   False                   False               False
# 2434                   False                   False               False
# 2435                   False                   False               False
# 2436                   False                   False               False
# 2437                   False                   False               False
# 2438                   False                   False               False
# 2439                   False                   False               False
# 2440                   False                   False               False
# 2441                   False                   False               False
# 2442                   False                   False               False
# 2443                   False                   False               False
# 2444                   False                   False               False
# 2445                   False                   False               False
# 2446                   False                   False               False
# 2447                   False                   False               False
# 2448                   False                   False               False
# 2449                   False                   False               False
# 2450                   False                   False               False
# 2451                   False                   False               False
# 2452                   False                   False               False
# 2453                   False                   False               False
# 2454                   False                   False               False
# 2455                   False                   False               False
# 2456                   False                   False               False
# 2457                   False                   False               False
# 2458                   False                   False               False
# 2459                   False                   False               False
# 2460                   False                   False               False
#
#      primary_class_nan
# 790              False
# 792              False
# 802              False
# 805              False
# 808              False
# 810              False
# 812              False
# 819              False
# 821              False
# 822              False
# 824              False
# 832              False
# 834              False
# 838              False
# 839              False
# 840              False
# 841              False
# 845              False
# 850              False
# 863              False
# 870              False
# 887              False
# 888              False
# 893              False
# 930              False
# 931              False
# 943              False
# 944              False
# 945              False
# 947              False
# ...                ...
# 2431             False
# 2432             False
# 2433             False
# 2434             False
# 2435             False
# 2436             False
# 2437             False
# 2438             False
# 2439             False
# 2440             False
# 2441             False
# 2442             False
# 2443             False
# 2444             False
# 2445             False
# 2446             False
# 2447             False
# 2448             False
# 2449             False
# 2450             False
# 2451             False
# 2452             False
# 2453             False
# 2454             False
# 2455             False
# 2456             False
# 2457             False
# 2458             False
# 2459             False
# 2460             False
#
# [779 rows x 2211 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

# %%
y = target.values
X = df_rf_features.values

# %%
from sklearn import preprocessing
# min_max_scaler = preprocessing.MinMaxScaler()
# X_scaled = min_max_scaler.fit_transform(X)
# X_scaled = preprocessing.MinMaxScaler(X)
X_scaled = X

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=2, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0)

# %%
print "score:", rf.score(X_test, y_test)
# Out:
# score: 0.748717948718

# %%
y_predict = rf.predict(X_test)
print "confusion matrix:"
print confusion_matrix(y_test, y_predict)
# Out:
# confusion matrix:
# [[ 10  40]
#  [  9 136]]

# %% [raw]
# initial model result:
# confusion matrix:
# [[ 12  33]
#  [ 10 140]]

# %%
print "precision:", precision_score(y_test, y_predict)
print "recall:", recall_score(y_test, y_predict)
# Out:
# precision: 0.772727272727
# recall: 0.937931034483

# %% [raw]
# initial model result:
# precision: 0.809248554913
# recall: 0.933333333333

# %%
rf = RandomForestClassifier(n_estimators=30, oob_score=True)
rf.fit(X_train, y_train)
print "accuracy score:", rf.score(X_test, y_test)
print "out of bag score:", rf.oob_score_
# Out:
# accuracy score: 0.789743589744
# out of bag score: 0.765410958904

# %% [raw]
# initial model result:
# accuracy score: 0.774358974359
# out of bag score: 0.739726027397

# %%
feature_importances = np.argsort(rf.feature_importances_)
print "top nine:", list(df_rf_features.columns[feature_importances[-1:-10:-1]])
# Out:
# top nine: ['bwd_cit_ratio_inv_exm', 'fwd_cit_ratio_inv_exm', 'npl-citations', u'id', u'seq', u'comprising', u'said', u'acid', u'claim']

# %%
n = 10 # top 10 features

importances = rf.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(n):
    print("%d. %s (%f)" % (f + 1, df_rf_features.columns[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. bwd_cit_ratio_inv_exm (0.040917)
# 2. fwd_cit_ratio_inv_exm (0.029501)
# 3. npl-citations (0.017257)
# 4. id (0.016580)
# 5. seq (0.012282)
# 6. comprising (0.011843)
# 7. said (0.009578)
# 8. acid (0.009395)
# 9. claim (0.008750)
# 10. amino (0.008385)

# %% [raw]
# initial model result:
# Feature ranking:
# 1. npl-citations (0.031593)
# 2. num_of_claims (0.015524)
# 3. fwd_cit_ratio_inv_exm (0.013426)
# 4. bwd_cit_ratio_inv_exm (0.005213)
# 5. bwd_pat_cit_count (0.003833)
# 6. 000 (0.001029)
# 7. 0001 (0.000143)
# 8. 001 (0.000000)
# 9. 01 (0.000000)
# 10. 0101 (0.000000)

# %%
std
# Out:
# array([ 0.02341346,  0.0062631 ,  0.03919298, ...,  0.00163778,
#         0.        ,  0.        ])

# %%
num_trees = range(5, 50, 5)
accuracies = []
for n in num_trees:
    tot = 0
    for i in xrange(5):
        rf = RandomForestClassifier(n_estimators=n)
        rf.fit(X_train, y_train)
        tot += rf.score(X_test, y_test)
    accuracies.append(tot / 5)
plt.plot(num_trees, accuracies)
plt.show()

# %%
def plot_roc(X, y, clf_class, **kwargs):
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    kf = KFold(len(y), n_folds=5, shuffle=True)
    y_prob = np.zeros((len(y),2))
    mean_tpr = 0.0
    mean_fpr = np.linspace(0, 1, 100)
    all_tpr = []
    fig = plt.figure(figsize=(12, 8))

    for i, (train_index, test_index) in enumerate(kf):
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        # Predict probabilities, not classes
        y_prob[test_index] = clf.predict_proba(X_test)
        fpr, tpr, thresholds = roc_curve(y[test_index], y_prob[test_index, 1])
        mean_tpr += interp(mean_fpr, fpr, tpr)
        mean_tpr[0] = 0.0
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))
    mean_tpr /= len(kf)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, 'k--',label='Mean ROC (area = %0.2f)' % mean_auc, lw=2)
    
    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Random')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
plt.figure()
plt.title("Feature importances")
plt.bar(range(10), importances[indices], yerr=std[indices], color="r", align="center")
plt.xticks(range(10), indices) # df_rf_features.columns[indices])
plt.xlim([-1, 10])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-59-1554625039a5> in <module>()
#       1 plt.figure()
#       2 plt.title("Feature importances")
# ----> 3 plt.bar(range(10), importances[indices], yerr=std[indices], color="r", align="center")
#       4 plt.xticks(range(10), indices) # df_rf_features.columns[indices])
#       5 plt.xlim([-1, 10])
#
# /Users/youngstone/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, **kwargs)
#    2566         ax.hold(hold)
#    2567     try:
# -> 2568         ret = ax.bar(left, height, width=width, bottom=bottom, **kwargs)
#    2569         draw_if_interactive()
#    2570     finally:
#
# /Users/youngstone/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    1989         assert len(height) == nbars, ("incompatible sizes: argument 'height' "
#    1990                                       "must be length %d or scalar" %
# -> 1991                                       nbars)
#    1992         assert len(width) == nbars, ("incompatible sizes: argument 'width' "
#    1993                                      "must be length %d or scalar" %
#
# AssertionError: incompatible sizes: argument 'height' must be length 10 or scalar

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.cross_validation import KFold
from sklearn.preprocessing import StandardScaler



def plot_roc(X, y, clf_class, **kwargs):
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    kf = KFold(len(y), n_folds=5, shuffle=True)
    y_prob = np.zeros((len(y),2))
    mean_tpr = 0.0
    mean_fpr = np.linspace(0, 1, 100)
    all_tpr = []
    for i, (train_index, test_index) in enumerate(kf):
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        # Predict probabilities, not classes
        y_prob[test_index] = clf.predict_proba(X_test)
        fpr, tpr, thresholds = roc_curve(y[test_index], y_prob[test_index, 1])
        mean_tpr += interp(mean_fpr, fpr, tpr)
        mean_tpr[0] = 0.0
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=1, label='ROC fold %d (area = %0.2f)' % (i, roc_auc))
    mean_tpr /= len(kf)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    plt.plot(mean_fpr, mean_tpr, 'k--',label='Mean ROC (area = %0.2f)' % mean_auc, lw=2)
    
    plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Random')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %%
# 16. Run all the other classifiers that we have learned so far in class
def get_scores(classifier, X_train, X_test, y_train, y_test, **kwargs):
    model = classifier(**kwargs)
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    return model.score(X_test, y_test), \
           precision_score(y_test, y_predict), \
           recall_score(y_test, y_predict), \
           f1_score(y_test, y_predict)

print "    Model, Accuracy, Precision, Recall, F1-Score"
print "    Random Forest:", get_scores(RandomForestClassifier, X_train, X_test, y_train, y_test, n_estimators=25, max_features=5)
print "    Logistic Regression:", get_scores(LogisticRegression, X_train, X_test, y_train, y_test)
print "    Decision Tree:", get_scores(DecisionTreeClassifier, X_train, X_test, y_train, y_test)
print "    SVM:", get_scores(SVC, X_train, X_test, y_train, y_test)
print "    Naive Bayes:", get_scores(MultinomialNB, X_train, X_test, y_train, y_test)
## MODEL               ACCURACY PRECISION    RECALL
## Random Forest         0.9508    0.8817    0.7321
## Logistic Regression   0.8741    0.6129    0.1696
## Decision Tree         0.9209    0.6949    0.7321

print "    Use the included `plot_roc` function to visualize the roc curve of each model"
plot_roc(X, y, RandomForestClassifier, n_estimators=25, max_features=5)
plot_roc(X, y, LogisticRegression)
plot_roc(X, y, DecisionTreeClassifier)
# plot_roc(X, y, SVC)
plot_roc(X, y, MultinomialNB)
# Out:
#     Model, Accuracy, Precision, Recall, F1-Score
#     Random Forest:
# (0.7384615384615385, 0.74736842105263157, 0.97931034482758617, 0.84776119402985073)
#     Logistic Regression: (0.78974358974358971, 0.80952380952380953, 0.93793103448275861, 0.86900958466453682)
#     Decision Tree:
# (0.74358974358974361, 0.80645161290322576, 0.86206896551724133, 0.83333333333333337)
#     SVM:
# (0.74358974358974361, 0.76243093922651939, 0.9517241379310345, 0.84662576687116564)
#     Naive Bayes: (0.7384615384615385, 0.80128205128205132, 0.86206896551724133, 0.83056478405315615)
#     Use the included `plot_roc` function to visualize the roc curve of each model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-820af6a5025a> in <module>()
#      22 plot_roc(X, y, DecisionTreeClassifier)
#      23 # plot_roc(X, y, SVC)
# ---> 24 plot_roc(X, y, MultinomialNB)
#
# <ipython-input-62-f0410e3aa2fd> in plot_roc(X, y, clf_class, **kwargs)
#      20         y_train = y[train_index]
#      21         clf = clf_class(**kwargs)
# ---> 22         clf.fit(X_train,y_train)
#      23         # Predict probabilities, not classes
#      24         y_prob[test_index] = clf.predict_proba(X_test)
#
# /Users/youngstone/anaconda/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in fit(self, X, y, sample_weight)
#     322         self.feature_count_ = np.zeros((n_effective_classes, n_features),
#     323                                        dtype=np.float64)
# --> 324         self._count(X, Y)
#     325         self._update_feature_log_prob()
#     326         self._update_class_log_prior(class_prior=class_prior)
#
# /Users/youngstone/anaconda/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in _count(self, X, Y)
#     424         """Count and smooth feature occurrences."""
#     425         if np.any((X.data if issparse(X) else X) < 0):
# --> 426             raise ValueError("Input X must be non-negative")
#     427         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     428         self.class_count_ += Y.sum(axis=0)
#
# ValueError: Input X must be non-negative

# %%
rf_grid = {'max_depth': [3, None],
           'max_features': ['sqrt', 'log2', 10, 20, 40],
           'min_samples_split': [1, 3, 10],
           'min_samples_leaf': [1, 3, 10],
           'bootstrap': [True, False],
           'n_estimators': [25, 40, 50],
           'random_state': [1]}

# %%
def grid_search(est, grid):
    grid_cv = GridSearchCV(est, grid, n_jobs=-1, verbose=True,
                           scoring='precision').fit(X_train, y_train)
    return grid_cv

# %%
rf_grid_search = grid_search(RandomForestClassifier(), rf_grid)

rf_best = rf_grid_search.best_estimator_
print rf_grid_search.best_params_

print "score:", rf_best.score(X_test, y_test)
y_predict = rf_best.predict(X_test)
print "confusion matrix:"
print confusion_matrix(y_test, y_predict)
print "precision:", precision_score(y_test, y_predict)
print "recall:", recall_score(y_test, y_predict)
# Out:
# Fitting 3 folds for each of 540 candidates, totalling 1620 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  50 jobs       | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 200 jobs       | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 450 jobs       | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 800 jobs       | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 1250 jobs       | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done 1606 out of 1620 | elapsed:   52.9s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 1620 out of 1620 | elapsed:   53.4s finished
# {'bootstrap': False, 'min_samples_leaf': 1, 'n_estimators': 25, 'min_samples_split': 1, 'random_state': 1, 'max_features': 'sqrt', 'max_depth': None}
# score: 0.789743589744
# confusion matrix:
# [[ 12  38]
#  [  3 142]]
# precision: 0.788888888889
# recall: 0.979310344828

# %% [raw]
# initial result:
# score: 0.810256410256
# confusion matrix:
# [[ 12  33]
#  [  4 146]]
# precision: 0.815642458101
# recall: 0.973333333333

# %%
rf_best.feature_importances_
# Out:
# array([ 0.01065365,  0.00671505,  0.01627091, ...,  0.00066891,
#         0.        ,  0.        ])

# %%
importances = rf_best.feature_importances_[:n]
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(n):
    print("%d. %s (%f)" % (f + 1, df_rf_features.columns[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. bwd_cit_ratio_inv_exm (0.049454)
# 2. fwd_cit_ratio_inv_exm (0.016271)
# 3. npl-citations (0.010654)
# 4. num_of_claims (0.006715)
# 5. bwd_pat_cit_count (0.006656)
# 6. 11 (0.003878)
# 7. 12 (0.003185)
# 8. 10 (0.002582)
# 9. 13 (0.002005)
# 10. 100 (0.001089)
# 11. 117 (0.000841)
# 12. 120 (0.000695)
# 13. 124 (0.000672)
# 14. 121 (0.000635)
# 15. 107 (0.000504)
# 16. 123 (0.000453)
# 17. 106 (0.000350)
# 18. 01 (0.000326)
# 19. 000 (0.000322)
# 20. 108 (0.000317)
# 21. 111 (0.000299)
# 22. 126 (0.000290)
# 23. 103 (0.000274)
# 24. 104 (0.000190)
# 25. 001 (0.000148)
# 26. 132 (0.000121)
# 27. 105 (0.000109)
# 28. 0001 (0.000000)
# 29. 131 (0.000000)
# 30. 129 (0.000000)
# 31. 0101 (0.000000)
# 32. 130 (0.000000)
# 33. 128 (0.000000)
# 34. 1000 (0.000000)
# 35. 101 (0.000000)
# 36. 102 (0.000000)
# 37. 127 (0.000000)
# 38. 109 (0.000000)
# 39. 110 (0.000000)
# 40. 116 (0.000000)
# 41. 118 (0.000000)
# 42. 119 (0.000000)
# 43. 122 (0.000000)
# 44. 125 (0.000000)
# 45. 133 (0.000000)

# %%
y_predict = rf_best.predict(X_test)
print "confusion matrix:"
print confusion_matrix(y_test, y_predict)
print "precision:", precision_score(y_test, y_predict)
print "recall:", recall_score(y_test, y_predict)
print "f1-score:", f1_score(y_test, y_predict)
# Out:
# confusion matrix:
# [[ 12  38]
#  [  3 142]]
# precision: 0.788888888889
# recall: 0.979310344828
# f1-score: 0.873846153846
