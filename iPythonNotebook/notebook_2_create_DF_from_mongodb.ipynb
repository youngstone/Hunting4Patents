# %%
import json
from pymongo import MongoClient
from pymongo.errors import DuplicateKeyError, CollectionInvalid
import datetime as dt
import pandas as pd
import pickle
import re
import numpy as np

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.patent_database
collection = db.patent_fields

# %%
data = collection.find({},{"_id":0})

# %%
df_raw = pd.DataFrame(columns=[u'Number', u'Title', u'Filing Date', u'US Patent References',  u'Abstract', u'Other Classes', u'Primary Class', u'Claims'])

# %%
df_raw
# Out:
# Empty DataFrame
# Columns: [Number, Title, Filing Date, US Patent References, Abstract, Other Classes, Primary Class, Claims]
# Index: []

# %%
for i in data:
    df_raw = df_raw.append([i])

# %%
df = df_raw

# %%
df['Title']
# Out:
# 0                                  Peptide composition
# 0                                 Senescence inhibitor
# 0    Aspergillus vaccine preparation and methods of...
# 0    Method of treating cancer with an HLA-A*3303-r...
# 0    FVIII peptides for immune tolerance induction ...
# 0    Modulation of developmental immune programming...
# 0    Immunotherapy against several tumors including...
# 0                Surface-coated structures and methods
# 0                               Epsigam fusion protein
# 0    Targeting the neuromuscular junction for treat...
# 0    ***WITHDRAWN PATENT AS PER THE LATEST USPTO WI...
# 0    Anti-HIV vaccine constructed based on amino ac...
# 0            Recombinant fusion interferon for animals
# 0    Peptidic antagonists of class III semaphorins/...
# 0    Vaccine vectors and methods of enhancing immun...
# ...
# 0          Immunonodulating compositions and their use
# 0    Recombinantly expressed rabbit zona pellucida ...
# 0    DNA fragments coding an immunogen peptide liab...
# 0      Hyposensitization agent of cedar pollen antigen
# 0    Antibodies to inhibin and conjugates produced ...
# 0                                   Rotavirus antigens
# 0    Methods and compositions for immunologically m...
# 0    Synthetic peptides and use thereof in preparin...
# 0    LHRH analogues useful in stimulating anti-LHRH...
# 0    Safe vaccine for hepatitis containing polymeri...
# 0    Identification and preparation of epitopes on ...
# 0    Muramyl peptides and processes for their manuf...
# 0    Synthetic ST toxin, process for its preparatio...
# 0    Synthetic peptides corresponding to antigenic ...
# 0    Antigenically active polypeptide and a process...
# Name: Title, Length: 2465, dtype: object

# %%
df.head()
# Out:
#     Number                                              Title Filing Date  \
# 0  8961986                                Peptide composition  12/06/2012
# 0  8962678                               Senescence inhibitor  06/29/2007
# 0  8449894  Aspergillus vaccine preparation and methods of...  05/25/2007
# 0  8968745  Method of treating cancer with an HLA-A*3303-r...  12/31/2013
# 0  8969524  FVIII peptides for immune tolerance induction ...  10/27/2011
#
#                                 US Patent References  \
# 0  [/8623827.html, /y2010/0286054.html, /y2008/02...
# 0  [/y2009/0148554.html, /y2007/0149619.html, /y2...
# 0  [/y2005/0281816.html, /6800290.html, /6248329....
# 0  [/y2010/0292160.html, /y2008/0152631.html, /y2...
# 0         [/y2010/0168018.html, /y2005/0256304.html]
#
#                                             Abstract  \
# 0  There is provided a method for selecting a tol...
# 0  Provision of a drug, a quasi-drug, and a food ...
# 0  The present invention relates to compositions ...
# 0  Disclosed are: a peptide comprising an amino a...
# 0  The present invention is related to peptides t...
#
#                                        Other Classes Primary Class  \
# 0  514/1.1,                                    51...     424/185.1
# 0                                          424/185.1       514/456
# 0  424/184.1,                                    ...     424/274.1
# 0  514/19.3,                                    5...     424/184.1
# 0  530/300,                                    53...       530/383
#
#                                               Claims
# 0  The invention claimed is:\n                1. ...
# 0  The invention claimed is:\n                1. ...
# 0  What is claimed is:\n                1.  A com...
# 0  The invention claimed is:\n                1. ...
# 0  What is claimed is:\n                1.  An im...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2465 entries, 0 to 0
# Data columns (total 8 columns):
# Number                  2465 non-null object
# Title                   2465 non-null object
# Filing Date             2465 non-null object
# US Patent References    2465 non-null object
# Abstract                2465 non-null object
# Other Classes           2439 non-null object
# Primary Class           2465 non-null object
# Claims                  2465 non-null object
# dtypes: object(8)

# %%
def func_clean_reference(citations):
    if citations:
        result = []
        for cite in citations:
            result.append("".join(re.findall('\d+', cite)))
        return result

# %%
def func_clean_class(classes):
    if classes:
        result = [cls.strip() for cls in classes.split(',')]
        return result

# %%
def func_clean_claim(claims):
    if claims:
        result = [clm.strip() for clm in claims.split('\n')][1:]
        return ' '.join(result)

# %%
df['US Patent References'] = df['US Patent References'].apply(func_clean_reference)

# %%
df['Filing Date'] = pd.to_datetime(df['Filing Date'])

# %%
df['Other Classes'] = df['Other Classes'].apply(func_clean_class)

# %%
df['Primary Class'] = df['Primary Class'].apply(func_clean_class)

# %%
df['Claims'] = df['Claims'].apply(func_clean_claim)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2465 entries, 0 to 0
# Data columns (total 8 columns):
# Number                  2465 non-null object
# Title                   2465 non-null object
# Filing Date             2465 non-null datetime64[ns]
# US Patent References    2051 non-null object
# Abstract                2465 non-null object
# Other Classes           2439 non-null object
# Primary Class           2465 non-null object
# Claims                  2465 non-null object
# dtypes: datetime64[ns](1), object(7)

# %%
df = df.set_index(np.arange(df.shape[0]))

# %%
df.iloc[10]['Title']
# Out:
# u'***WITHDRAWN PATENT AS PER THE LATEST USPTO WITHDRAWN LIST***Multi-component biological transport systems'

# %%
df
# Out:
#        Number                                              Title Filing Date  \
# 0     8961986                                Peptide composition  2012-12-06
# 1     8962678                               Senescence inhibitor  2007-06-29
# 2     8449894  Aspergillus vaccine preparation and methods of...  2007-05-25
# 3     8968745  Method of treating cancer with an HLA-A*3303-r...  2013-12-31
# 4     8969524  FVIII peptides for immune tolerance induction ...  2011-10-27
# 5     8961982  Modulation of developmental immune programming...  2008-06-13
# 6     8961985  Immunotherapy against several tumors including...  2012-01-09
# 7     8961984              Surface-coated structures and methods  2010-10-07
# 8     8961992                             Epsigam fusion protein  2014-04-02
# 9     8961981  Targeting the neuromuscular junction for treat...  2012-06-19
# 10    8962548  ***WITHDRAWN PATENT AS PER THE LATEST USPTO WI...  2005-03-03
# 11    8956620  Anti-HIV vaccine constructed based on amino ac...  2009-05-27
# 12    8956623          Recombinant fusion interferon for animals  2013-07-17
# 13    8956622  Peptidic antagonists of class III semaphorins/...  2006-06-28
# 14    8956618  Vaccine vectors and methods of enhancing immun...  2011-01-21
# 2463  4454121  Synthetic peptides corresponding to antigenic ...  1982-07-27
# 2464  4107298  Antigenically active polypeptide and a process...  1977-04-21
#
#                                    US Patent References  \
# 0     [8623827, 20100286054, 20080200368, 5989565, 5...
# 1     [20090148554, 20070149619, 20070149466, 200700...
# 2                       [20050281816, 6800290, 6248329]
# 3     [20100292160, 20080152631, 20070082860, 714458...
# 4                            [20100168018, 20050256304]
# 5     [7090855, 6838452, 6825318, 20030114367, 20030...
# 6     [8008431, 20100029573, 20100021441, 2003017573...
# 7                                                  None
# 8     [7566456, 7544783, 7488804, 7265208, 200401989...
# 9     [7884188, 20090209459, 20060013809, 2005026601...
# 10    [8092788, 20070077259, 7138105, 7060498, 70566...
# 11                                        [20020146683]
# 12    [20120128624, 8084021, 7833533, 20090280085, 7...
# 13                               [6900288, 20030105000]
# 14    [7928213, 20110020318, 20100292309, 2010029110...
# 15                  [20070025978, 20060160121, 5604109]
# 16    [20090148466, 20080286311, 7288256, 2007006546...
# 17    [20130136740, 8338569, 20120301921, 2012025153...
# 18                                                 None
# 19              [20090170798, 20090004144, 20080050383]
# 20    [20090247450, 20080026046, 5919757, 5919443, 5...
# 21                               [20040043438, 6610297]
# 22                                                 None
# 23    [20110255184, 7446185, 7211432, 7179645, 20050...
# 24    [20090292113, 7504482, 20070207163, 7074896, 6...
# 25                                                 None
# 26    [20100292160, 20080152631, 20070082860, 714458...
# 27    [8512709, 20120244184, 8106015, 6787523, 5589154]
# 28    [7541034, 7521054, 7470775, 7368110, 7355012, ...
# 29    [20070280953, 20070192905, 20070136896, 200302...
# ...                                                 ...
# 2435                                 [4946945, 4163778]
# 2436                                               None
# 2437  [5194425, 5130297, 4762915, 4714759, 4681760, ...
# 2438                                 [4719177, 4603112]
# 2439                                          [4853326]
# 2440               [4713366, 4707357, 4515920, 4289872]
# 2441      [4843146, 4707357, 4409141, 4132746, 3929756]
# 2442  [4762915, 4714759, 4675382, 4478823, 4400376, ...
# 2443                                          [4857634]
# 2444                                               None
# 2445  [4710381, 4650858, 4610880, 4522751, 4465623, ...
# 2446  [4806352, 4806350, 4803070, 4578269, 4517304, ...
# 2447                                          [4939239]
# 2448  [4536479, 4493795, 4474765, 4474757, 4454121, ...
# 2449               [4415491, 4401658, 4284537, 3985722]
# 2450  [4722840, 4707357, 4683136, 4599230, 4565696, ...
# 2451                        [4795634, 4526716, 3992520]
# 2452               [4751083, 4719177, 4694072, 4442205]
# 2453                                 [4432969, 4185090]
# 2454                        [4740587, 4493795, 4474757]
# 2455                                               None
# 2456                                          [4761371]
# 2457                                               None
# 2458      [4489061, 4481190, 4478744, 4377574, 3963691]
# 2459                                          [4046871]
# 2460      [4415491, 4284537, 4196265, 4172827, 4160019]
# 2461                                 [4414204, 4323560]
# 2462                                               None
# 2463                                               None
# 2464                        [4018753, 3960827, 3929756]
#
#                                                Abstract  \
# 0     There is provided a method for selecting a tol...
# 1     Provision of a drug, a quasi-drug, and a food ...
# 2     The present invention relates to compositions ...
# 3     Disclosed are: a peptide comprising an amino a...
# 4     The present invention is related to peptides t...
# 5     Maternal adaptive immunity conveys temporary h...
# 6     The present invention relates to peptides, nuc...
# 7     The present invention relates to a method for ...
# 8     Epsi-gam provides a novel fusion protein with ...
# 9     Compositions and methods for targeting therape...
# 10    Compositions and methods are provided that are...
# 11    Provided are antigenic polypeptides of HIV env...
# 12    The present invention relates to a recombinant...
# 13    The present invention concern a peptidic antag...
# 14    Provided herein are vaccine vectors including ...
# 15    The invention relates to the identification, s...
# 16    The present invention refers to recombinant AD...
# 17    Methods of treating cancer comprising administ...
# 18    This disclosure relates to modified Streptococ...
# 19    This invention relates to a vaccine for preven...
# 20    Provided are pharmaceutical liquid formulation...
# 21    The invention provides hypoallergenic variants...
# 22    The present invention discloses a multi-target...
# 23    This invention relates generally to identifyin...
# 24    The methods and compositions described herein ...
# 25    The present invention relates to compositions ...
# 26    Disclosed are: a peptide comprising an amino a...
# 27    An object of the present invention is to provi...
# 28    The present invention provides improved Pseudo...
# 29    A transformed soybean plant having a gene enco...
# ...                                                 ...
# 2435  Proteins, referred to as modified human T cell...
# 2436  The present invention is directed to a recombi...
# 2437  The invention is directed to methods and mater...
# 2438  Peptides or proteins related to a melanoma ass...
# 2439  A fragment capable of binding to an anti-CD43 ...
# 2440  Multiple antigen peptide systems are described...
# 2441  Synthetic polypeptides constituted by at least...
# 2442  The invention is directed to methods and mater...
# 2443  Disclosed is a synthetic peptide, useful as an...
# 2444  Disclosed herein is a synthetic senescent cell...
# 2445  An agent for the therapy of hemophilia A which...
# 2446  The present invention concerns novel immunogen...
# 2447  A novel hyposensitization agent was prepared b...
# 2448  Chemically synthesized polypeptides containing...
# 2449  A synthetic vaccine is contemplated comprising...
# 2450  Novel methods or compositions are provided for...
# 2451  The invention relates to antigenic preparation...
# 2452  DNA fragment capable of coding for an immunoge...
# 2453  A novel hyposensitization agent was prepared b...
# 2454  A 32,000-Dalton protein with inhibin activity ...
# 2455  A soluble form of the neutralizing antigen or ...
# 2456  The activity of growth-associated receptors is...
# 2457  The compounds of the present invention are syn...
# 2458  A conjugate between a nona- or decapeptide of ...
# 2459  Methods and compositions are provided for an i...
# 2460  An immunoglobulin is provided which consists e...
# 2461  The compounds of the formula I ##STR1## in whi...
# 2462  The invention relates to novel synthetic pepti...
# 2463  Synthetic peptides corresponding to antigenic ...
# 2464  The invention provides for a synthetic antigen...
#
#                                           Other Classes Primary Class  \
# 0                 [514/1.1, 514/17.9, 530/300, 530/326]   [424/185.1]
# 1                                           [424/185.1]     [514/456]
# 2                       [424/184.1, 424/185.1, 530/350]   [424/274.1]
# 3     [514/19.3, 514/19.4, 514/19.5, 514/19.6, 435/2...   [424/184.1]
# 4     [530/300, 530/324, 530/325, 530/338, 435/69.6,...     [530/383]
# 5     [424/185.1, 424/193.1, 514/1.9, 514/6.9, 514/1...   [424/184.1]
# 6                  [530/300, 530/328, 530/345, 514/1.1]   [424/185.1]
# 2449  [424/185.1, 424/186.1, 424/187.1, 424/189.1, 4...   [424/194.1]
# 2450  [424/185.1, 424/186.1, 424/190.1, 424/204.1, 4...   [424/184.1]
# 2451  [424/559, 424/811, 514/9.8, 530/350, 530/380, ...   [424/185.1]
# 2452       [424/185.1, 424/217.1, 435/91.41, 536/23.72]   [435/320.1]
# 2453  [424/185.1, 424/193.1, 424/276.1, 530/359, 530...     [530/370]
# 2454  [424/158.1, 424/185.1, 424/194.1, 424/195.11, ...   [424/139.1]
# 2455           [424/185.1, 424/215.1, 530/350, 930/220]     [530/324]
# 2456  [436/519, 436/543, 530/402, 530/403, 530/810, ...   [424/185.1]
# 2457  [424/185.1, 514/21.7, 530/326, 530/327, 530/32...    [514/21.6]
# 2458  [424/195.11, 424/198.1, 424/811, 514/10.3, 514...   [424/185.1]
# 2459            [424/227.1, 514/3.7, 514/4.3, 514/15.2]   [424/185.1]
# 2460  [424/185.1, 424/186.1, 424/187.1, 424/189.1, 4...     [530/324]
# 2461        [514/3.7, 514/20.9, 525/54.11, 930/DIG.500]   [424/185.1]
# 2462  [424/190.1, 424/257.1, 424/832, 514/2.8, 530/3...   [424/185.1]
# 2463  [514/2.6, 514/2.7, 514/21.3, 514/21.4, 514/21....   [424/185.1]
# 2464  [514/21.3, 530/326, 530/327, 530/329, 530/330,...   [424/185.1]
#
#                                                  Claims
# 0     1.  A method of inducing T cell tolerance to m...
# 1     1.  A method for inhibiting a condition accomp...
# 2     1.  A composition comprising an effective immu...
# 3     1.  A method for the treatment of cancer in a ...
# 4     1.  An immunogenic peptide consisting of the a...
# 5     1.  A method of immunization, comprising admin...
# 6     1.  A peptide consisting of the amino acid seq...
# 7     1.  A method of covalently attaching a compoun...
# 8     1.  A fusion protein comprising of the sequenc...
# 9     1.  A composition comprising a neuromuscular j...
# 10    1.  A method of transdermally administering a ...
# 11    1.  An antigenic polypeptide or a fragment the...
# 12    1.  A porcine recombinant fusion interferon re...
# 13    1.  A method for the treatment of a subject su...
# 14    1.  A vaccine vector comprising a first polynu...
# 15    1.  An isolated fusion polypeptide comprising ...
# 16    1.  A chimeric polypeptide comprising SEQ ID N...
# 17    1.  A method of treating cancer in a subject c...
# 18    1.  An isolated nucleic acid sequence encoding...
# 19    1.  A vaccine for treating tauopathy dementia,...
# 20    1.  A method for the treatment of cancer, seve...
# 21    1.  A protein which is a hypoallergenic varian...
# 22    1.  A multi-target fusion polypeptide comprisi...
# 23    1.  A method for treating a patient having tum...
# 24    1.  A compound of the formula X1—R0 (SEQ ID NO...
# 25    1.  A fusion protein selected from the group c...
# 26    1.  A method for the treatment of cancer in a ...
# 27    1.  A method for enhancing an immune response ...
# 28    1.  An isolated Pseudomonas exotoxin A (“PE”),...
# 29    1.  A transformed soybean plant comprising a g...
# ...                                                 ...
# 2435  1. A modified Fel d I, substantially free of o...
# 2436  1. A substantially pure recombinant mite aller...
# 2437  1. A method for preparing a pharmaceutical com...
# 2438  1. A recombinant virus, the genome of which co...
# 2439  1. A method of treating a human patient infect...
# 2440  1. An antigenic product comprising a dendritic...
# 2441  1. Synthetic, sequential polypeptides endowed ...
# 2442  1. A composition comprising an MHC Class II co...
# 2443  1. A synthetic peptide, useful as an immunocon...
# 2444  1. A peptide consisting essentially of a molec...
# 2445  1. An agent for the therapy of Factor VIII inh...
# 2446  1. Compound containing an amphiphilic adjuvant...
# 2447  1. A conjugate, which comprises a saccharide c...
# 2448  1. A synthetic polypeptide having an amino aci...
# 2449  1. A synthetic antigen comprising a carrier co...
# 2450  1. A method for modulating the immune response...
# 2451  covered under Letters Patent is: 1. A substant...
# 2452  1. A DNA fragment which codes for a protein th...
# 2453  1. A hyposensitization agent for the preventio...
# 2454  1. Antibodies generated by a mammalian immune ...
# 2455  1. A neutralizing antigen of rotavirus compris...
# 2456  1. A method for immunizing an animal against i...
# 2457  1. A synthetic peptide immunogen for use in de...
# 2458  1. An immunogen vaccine which induces in a man...
# 2459  1. A method for protecting a host susceptible ...
# 2460  1. A method of synthesizing a peptide comprisi...
# 2461  1. The compounds of the formula I ##STR20## wh...
# 2462  1. A peptide (P) n free of intramolecular disu...
# 2463  1. A synthetic polypeptide having the followin...
# 2464  1. Synthetic antigenically active polypeptide,...
#
# [2465 rows x 8 columns]

# %%
df.to_pickle('../data/patent_text_df.pkl')

# %%
df_from_pickle = pd.read_pickle('../data/dataframe.pkl')

# %%
df_from_pickle.head()
# Out:
#     Number                                              Title Filing Date  \
# 0  8961986                                Peptide composition  2012-12-06
# 1  8962678                               Senescence inhibitor  2007-06-29
# 2  8449894  Aspergillus vaccine preparation and methods of...  2007-05-25
# 3  8968745  Method of treating cancer with an HLA-A*3303-r...  2013-12-31
# 4  8969524  FVIII peptides for immune tolerance induction ...  2011-10-27
#
#                                 US Patent References  \
# 0  [8623827, 20100286054, 20080200368, 5989565, 5...
# 1  [20090148554, 20070149619, 20070149466, 200700...
# 2                    [20050281816, 6800290, 6248329]
# 3  [20100292160, 20080152631, 20070082860, 714458...
# 4                         [20100168018, 20050256304]
#
#                                             Abstract  \
# 0  There is provided a method for selecting a tol...
# 1  Provision of a drug, a quasi-drug, and a food ...
# 2  The present invention relates to compositions ...
# 3  Disclosed are: a peptide comprising an amino a...
# 4  The present invention is related to peptides t...
#
#                                        Other Classes Primary Class  \
# 0              [514/1.1, 514/17.9, 530/300, 530/326]   [424/185.1]
# 1                                        [424/185.1]     [514/456]
# 2                    [424/184.1, 424/185.1, 530/350]   [424/274.1]
# 3  [514/19.3, 514/19.4, 514/19.5, 514/19.6, 435/2...   [424/184.1]
# 4  [530/300, 530/324, 530/325, 530/338, 435/69.6,...     [530/383]
#
#                                               Claims
# 0  [1.  A method of inducing T cell tolerance to ...
# 1  [1.  A method for inhibiting a condition accom...
# 2  [1.  A composition comprising an effective imm...
# 3  [1.  A method for the treatment of cancer in a...
# 4  [1.  An immunogenic peptide consisting of the ...
